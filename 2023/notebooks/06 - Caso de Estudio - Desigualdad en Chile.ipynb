# %% [markdown]
# # Clase 06 - Caso de Estudio: Desigualdad en Chile

# %% [markdown]
# Profesor: **Fernando Becerra**, f.becerra@udd.cl, [www.fernandobecerra.com](www.fernandobecerra.com)

# %% [markdown]
# ##### Contexto
#
# [Discurso del presidente Boric en las Nacionaes Unidas](https://www.youtube.com/watch?v=EfTYTHtspeQ): "Nos duele ser uno de los países más desiguales del mundo"
#
# [Respuesta](https://www.latercera.com/opinion/noticia/es-chile-el-pais-mas-desigual-del-mundo/XYBKEGBTPBE3RB5NATYT4RNLSE/): "A partir de la última información disponible del Banco Mundial, en la región Colombia tiene un coeficiente de Gini de 54,2 (mayor el número es más desigual), Panamá (49,8), Costa Rica (49,3), Brasil (48,9), Guatemala (48,3), Honduras (48,2), Ecuador (47,3), Nicaragua (46,2), México (45,4), mientras Chile un 44,9."
#
# Discusión en Twitter: [baja del Gini a través de los años](https://twitter.com/ignaciobriones_/status/1572957052846346240), [trayectoria del Gini vs GDP](https://twitter.com/OLanderretche/status/1574571809466458113) ([inspiración](http://i0.wp.com/michelbaudin.com/wp-content/uploads/2013/05/brazil-gini-versus-gdp-chart.jpg))
#
#
# ##### Objetivo
# Hacer nuestro propio análisis más serio basado en la visualización y encontrar una historia que contar
#
# Inspiración: [Our World in Data](https://ourworldindata.org/income-inequality)

# %% [markdown]
# Lo primero es lo primero: importar lo típico

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# [World Bank](https://pip.worldbank.org/poverty-calculator)

# %%
df = pd.read_csv('../../datos/desigualdad/pip.csv')
df.head()
# Out:
#              region_name region_code country_name country_code  \
# 0     Sub-Saharan Africa         SSA       Angola          AGO
# 1     Sub-Saharan Africa         SSA       Angola          AGO
# 2     Sub-Saharan Africa         SSA       Angola          AGO
# 3  Europe & Central Asia         ECA      Albania          ALB
# 4  Europe & Central Asia         ECA      Albania          ALB
#
#    reporting_year reporting_level survey_acronym survey_coverage  survey_year  \
# 0            2000        national            HBS        national      2000.21
# 1            2008        national      IBEP-MICS        national      2008.50
# 2            2018        national          IDREA        national      2018.17
# 3            1996        national            EWS        national      1996.00
# 4            2002        national           LSMS        national      2002.00
#
#   welfare_type  ...   decile9  decile10       cpi         ppp  reporting_pop  \
# 0  consumption  ...  0.158687  0.402455  0.014200  107.269989       16395477
# 1  consumption  ...  0.162333  0.323117  0.303449  107.269989       21695636
# 2  consumption  ...  0.159390  0.396244  1.231024  107.269989       30809787
# 3  consumption  ...  0.148995  0.212156  0.399635   50.357372        3168033
# 4  consumption  ...  0.149251  0.254356  0.701637   50.357372        3051010
#
#    reporting_gdp  reporting_pce  is_interpolated  distribution_type  \
# 0    2451.509826            NaN            False              micro
# 1    4077.776844    1620.065607            False              micro
# 2    3595.106667    2093.495848            False              micro
# 3    1633.551572    1714.813416            False              micro
# 4    2247.497491    1685.368128            False              micro
#
#    estimation_type
# 0           survey
# 1           survey
# 2           survey
# 3           survey
# 4           survey
#
# [5 rows x 40 columns]

# %%
all_countries = df['country_name'].unique()

# %%
list(df.columns)
# Out:
# ['region_name',
#  'region_code',
#  'country_name',
#  'country_code',
#  'reporting_year',
#  'reporting_level',
#  'survey_acronym',
#  'survey_coverage',
#  'survey_year',
#  'welfare_type',
#  'survey_comparability',
#  'comparable_spell',
#  'poverty_line',
#  'headcount',
#  'poverty_gap',
#  'poverty_severity',
#  'watts',
#  'mean',
#  'median',
#  'mld',
#  'gini',
#  'polarization',
#  'decile1',
#  'decile2',
#  'decile3',
#  'decile4',
#  'decile5',
#  'decile6',
#  'decile7',
#  'decile8',
#  'decile9',
#  'decile10',
#  'cpi',
#  'ppp',
#  'reporting_pop',
#  'reporting_gdp',
#  'reporting_pce',
#  'is_interpolated',
#  'distribution_type',
#  'estimation_type']

# %%
df_chile = df[df['country_name'] == 'Chile']
df_chile
# Out:
#                    region_name region_code country_name country_code  \
# 322  Latin America & Caribbean         LAC        Chile          CHL
# 323  Latin America & Caribbean         LAC        Chile          CHL
# 324  Latin America & Caribbean         LAC        Chile          CHL
# 325  Latin America & Caribbean         LAC        Chile          CHL
# 326  Latin America & Caribbean         LAC        Chile          CHL
# 327  Latin America & Caribbean         LAC        Chile          CHL
# 328  Latin America & Caribbean         LAC        Chile          CHL
# 329  Latin America & Caribbean         LAC        Chile          CHL
# 330  Latin America & Caribbean         LAC        Chile          CHL
# 331  Latin America & Caribbean         LAC        Chile          CHL
# 332  Latin America & Caribbean         LAC        Chile          CHL
# 333  Latin America & Caribbean         LAC        Chile          CHL
# 334  Latin America & Caribbean         LAC        Chile          CHL
# 335  Latin America & Caribbean         LAC        Chile          CHL
# 336  Latin America & Caribbean         LAC        Chile          CHL
#
#      reporting_year reporting_level survey_acronym survey_coverage  \
# 322            1987        national          CASEN        national
# 323            1990        national          CASEN        national
# 324            1992        national          CASEN        national
# 325            1994        national          CASEN        national
# 326            1996        national          CASEN        national
# 327            1998        national          CASEN        national
# 328            2000        national          CASEN        national
# 329            2003        national          CASEN        national
# 330            2006        national          CASEN        national
# 331            2009        national          CASEN        national
# 332            2011        national          CASEN        national
# 333            2013        national          CASEN        national
# 334            2015        national          CASEN        national
# 335            2017        national          CASEN        national
# 336            2020        national          CASEN        national
#
#      survey_year welfare_type  ...   decile9  decile10       cpi         ppp  \
# 322       1987.0       income  ...  0.160075  0.453914  0.141201  478.995697
# 323       1990.0       income  ...  0.154096  0.470505  0.265681  478.995697
# 324       1992.0       income  ...  0.149427  0.451959  0.356878  478.995697
# 325       1994.0       income  ...  0.155901  0.459067  0.435449  478.995697
# 326       1996.0       income  ...  0.156687  0.444274  0.501988  478.995697
# 327       1998.0       income  ...  0.157075  0.449718  0.556358  478.995697
# 328       2000.0       income  ...  0.154262  0.425819  0.597324  478.995697
# 329       2003.0       income  ...  0.154101  0.413543  0.639934  478.995697
# 330       2006.0       income  ...  0.155561  0.378933  0.694008  478.995697
# 331       2009.0       income  ...  0.151857  0.382195  0.784435  478.995697
# 332       2011.0       income  ...  0.153459  0.372931  0.835362  478.995697
# 333       2013.0       income  ...  0.152660  0.373735  0.873375  478.995697
# 334       2015.0       income  ...  0.151542  0.360586  0.959573  478.995697
# 335       2017.0       income  ...  0.149540  0.363419  1.006627  478.995697
# 336       2020.0       income  ...  0.158416  0.357974  1.092927  478.995697
#
#      reporting_pop  reporting_gdp  reporting_pce  is_interpolated  \
# 322       12642917    4710.709892    2400.793312            False
# 323       13274617    5470.479736    2754.646852            False
# 324       13719818    6343.227129    3301.817823            False
# 325       14166346    6877.434435    3716.155714            False
# 326       14587367    7770.539111    4336.964275            False
# 327       14977736    8481.752131    4766.270043            False
# 328       15342350    8685.321794    4797.305129            False
# 329       15849649    9321.218536    5059.241111            False
# 330       16354507   10887.863776    6144.546774            False
# 331       16886184   11273.617502    6579.528584            False
# 332       17233584   12406.413571    7721.731971            False
# 333       17571511   13333.346834    8398.985217            False
# 334       17969356   13574.169238    8611.446615            False
# 335       18470435   13590.991346    8897.950706            False
# 336       19116209   12954.405354    8340.163281            False
#
#      distribution_type  estimation_type
# 322              micro           survey
# 323              micro           survey
# 324              micro           survey
# 325              micro           survey
# 326              micro           survey
# 327              micro           survey
# 328              micro           survey
# 329              micro           survey
# 330              micro           survey
# 331              micro           survey
# 332              micro           survey
# 333              micro           survey
# 334              micro           survey
# 335              micro           survey
# 336              micro           survey
#
# [15 rows x 40 columns]

# %% [markdown]
# [gráfico de Briones](https://twitter.com/ignaciobriones_/status/1572957052846346240)

# %%
df_chile.plot(x='reporting_year', y='gini')
# Out:
# <AxesSubplot:xlabel='reporting_year'>

# %% [markdown]
# [gráfico de Landerretche](https://twitter.com/OLanderretche/status/1574571809466458113) y [Kaiser](https://twitter.com/AXELKAISER/status/1575141702091780096)

# %%
df_chile.plot(x='reporting_gdp', y='gini')
# Out:
# <AxesSubplot:xlabel='reporting_gdp'>

# %% [markdown]
# ## Parte 2: Contexto latinoamericano

# %%
df['region_name'].unique()
# Out:
# array(['Sub-Saharan Africa', 'Europe & Central Asia',
#        'Other High Income Countries', 'Latin America & Caribbean',
#        'South Asia', 'East Asia & Pacific', 'Middle East & North Africa'],
#       dtype=object)

# %%
df_lac = df[df['region_name'] == 'Latin America & Caribbean']
df_lac.head()
# Out:
#                   region_name region_code country_name country_code  \
# 19  Latin America & Caribbean         LAC    Argentina          ARG
# 20  Latin America & Caribbean         LAC    Argentina          ARG
# 21  Latin America & Caribbean         LAC    Argentina          ARG
# 22  Latin America & Caribbean         LAC    Argentina          ARG
# 23  Latin America & Caribbean         LAC    Argentina          ARG
#
#     reporting_year reporting_level survey_acronym survey_coverage  \
# 19            1980           urban            EPH           urban
# 20            1986           urban            EPH           urban
# 21            1987           urban            EPH           urban
# 22            1991           urban            EPH           urban
# 23            1992           urban            EPH           urban
#
#     survey_year welfare_type  ...   decile9  decile10         cpi       ppp  \
# 19       1980.0       income  ...  0.163836  0.301754    0.054894  10.80794
# 20       1986.0       income  ...  0.163225  0.322081    0.014070  10.80794
# 21       1987.0       income  ...  0.163314  0.342519    0.032549  10.80794
# 22       1991.0       income  ...  0.159374  0.366093  328.909183  10.80794
# 23       1992.0       income  ...  0.165745  0.342871    0.038808  10.80794
#
#     reporting_pop  reporting_gdp  reporting_pce  is_interpolated  \
# 19       23122598   10318.182985            NaN            False
# 20       26230730    9412.994813            NaN            False
# 21       26769634    9517.108610            NaN            False
# 22       28887231    8769.750400            NaN            False
# 23       29352237    9338.699517            NaN            False
#
#     distribution_type  estimation_type
# 19              group           survey
# 20              micro           survey
# 21              micro           survey
# 22              micro           survey
# 23              micro           survey
#
# [5 rows x 40 columns]

# %%
countries = df_lac['country_name'].unique()
countries
# Out:
# array(['Argentina', 'Belize', 'Bolivia', 'Brazil', 'Chile', 'Colombia',
#        'Costa Rica', 'Dominican Republic', 'Ecuador', 'Guatemala',
#        'Guyana', 'Honduras', 'Haiti', 'Jamaica', 'St. Lucia', 'Mexico',
#        'Nicaragua', 'Panama', 'Peru', 'Paraguay', 'El Salvador',
#        'Suriname', 'Trinidad and Tobago', 'Uruguay', 'Venezuela, RB'],
#       dtype=object)

# %%
countries = ['Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia',
       'Costa Rica', 'Dominican Republic', 'Ecuador', 'Guatemala', 'Honduras', 'Mexico',
       'Nicaragua', 'Panama', 'Peru', 'Paraguay', 'El Salvador', 'Uruguay', 'Venezuela, RB']

fig, ax = plt.subplots(1,1, figsize=(8,6))

for country in countries:
    df_country = df_lac[(df_lac['country_name'] == country) & (df_lac['reporting_year'] >= 1990)]
    color = 'red' if country == 'Chile' else 'lightgray'
    df_country.plot(x='reporting_year', y='gini', color=color, ax=ax, legend=False)

# %%
countries = ['Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia',
       'Costa Rica', 'Dominican Republic', 'Ecuador', 'Guatemala', 'Honduras', 'Mexico',
       'Nicaragua', 'Panama', 'Peru', 'Paraguay', 'El Salvador', 'Uruguay', 'Venezuela, RB']

fig, ax = plt.subplots(1,1, figsize=(8,6))

for country in countries:
    df_country = df_lac[(df_lac['country_name'] == country) & (df_lac['reporting_year'] >= 1990)]
    color = 'red' if country == 'Chile' else 'lightgray'
    df_country.plot(x='reporting_gdp', y='gini', color=color, ax=ax, legend=False)

# %%
fig, ax = plt.subplots(1,1, figsize=(8,6))

for country in all_countries:
    df_1990 = df[(df['country_name'] == country) & (df['reporting_year'] == 1990)]
    df_2020 = df[(df['country_name'] == country) & (df['reporting_year'] == 2020)]
    if (df_1990.shape[0] != 1 or df_2020.shape[0] != 1):
        continue
    color = 'red' if country == 'Chile' else 'lightgray'
    ax.scatter(df_1990['gini'], df_2020['gini'], color=color)
    
plt.show()

# %% [markdown]
# [OWID data](https://ourworldindata.org/grapher/gini-index-of-income-in-2015-vs-1990-gcip-including-non-survey-years)

# %%
df_gini = pd.read_csv("../../datos/desigualdad/gini-index-of-income-in-2015-vs-1990-gcip-including-non-survey-years.csv")
df_gini.head()
# Out:
#         Entity Code   Year  \
# 0  Afghanistan  AFG   2015
# 1  Afghanistan  AFG -10000
# 2  Afghanistan  AFG  -9000
# 3  Afghanistan  AFG  -8000
# 4  Afghanistan  AFG  -7000
#
#    Gini index of income in 2015 (inc. non-survey years)  \
# 0                                           36.81118
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Gini index of income in 1990 (inc. non-survey years)  \
# 0                                           36.81118
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Population (historical estimates)                 Country grouping
# 0                           33753500  Eastern Europe and Central Asia
# 1                              14737                              NaN
# 2                              20405                              NaN
# 3                              28253                              NaN
# 4                              39120                              NaN

# %%
df_gini['Country grouping'].unique()
# Out:
# array(['Eastern Europe and Central Asia', nan,
#        'Middle East and North Africa', 'Sub-Saharan Africa',
#        'Latin America and Caribbean', 'Advanced industrial economies',
#        'South Asia', 'East Asia and Pacific'], dtype=object)

# %%
fig, ax = plt.subplots(1,1, figsize=(8,6)) 
xmin, xmax = 18, 85

for country in df_gini['Entity'].unique():
    df_country = df_gini[(df_gini['Entity'] == country)]
    x = df_country[df_country['Year'] == 2015]['Gini index of income in 1990 (inc. non-survey years)'].item()
    y = df_country[df_country['Year'] == 2015]['Gini index of income in 2015 (inc. non-survey years)'].item()
    if country == 'Chile':
        color = 'steelblue'
        alpha = 1.0
    elif df_country[df_country['Year'] == 2015]['Country grouping'].item() == 'Latin America and Caribbean':
        color = 'orange'
        alpha = 0.5
    else:
        color = 'lightgray'
        alpha = 0.5
    ax.scatter(x, y, color=color, alpha=alpha)
    
ax.plot([xmin, xmax], [xmin, xmax], '--', color='#d2d2d2')
ax.set_xlim([xmin, xmax])
ax.set_ylim([22, 68])
plt.show()

# %% [markdown]
# ## Parte 3: Perros grandes

# %% [markdown]
# [datos OCDE](https://stats.oecd.org/Index.aspx?DataSetCode=IDD)

# %%
df_ocde = pd.read_csv('../../datos/desigualdad/IDD_30092022043102297.csv')
df_ocde.head()
# Out:
#   LOCATION    Country MEASURE  \
# 0      AUS  Australia    GINI
# 1      AUS  Australia    GINI
# 2      AUS  Australia    GINI
# 3      AUS  Australia    GINI
# 4      AUS  Australia    GINI
#
#                                              Measure  AGE         Age group  \
# 0  Gini (disposable income, post taxes and transf...  TOT  Total population
# 1  Gini (disposable income, post taxes and transf...  TOT  Total population
# 2  Gini (disposable income, post taxes and transf...  TOT  Total population
# 3  Gini (disposable income, post taxes and transf...  TOT  Total population
# 4  Gini (disposable income, post taxes and transf...  TOT  Total population
#
#   DEFINITION          Definition   METHODO                       Methodology  \
# 0    CURRENT  Current definition  METH2012  New income definition since 2012
# 1    CURRENT  Current definition  METH2012  New income definition since 2012
# 2    CURRENT  Current definition  METH2012  New income definition since 2012
# 3    CURRENT  Current definition  METH2012  New income definition since 2012
# 4    CURRENT  Current definition  METH2011      Income definition until 2011
#
#    ...  Year  Unit Code       Unit PowerCode Code  PowerCode  \
# 0  ...  2012     0_TO_1  0-1 scale              0      Units
# 1  ...  2014     0_TO_1  0-1 scale              0      Units
# 2  ...  2016     0_TO_1  0-1 scale              0      Units
# 3  ...  2018     0_TO_1  0-1 scale              0      Units
# 4  ...  2004     0_TO_1  0-1 scale              0      Units
#
#   Reference Period Code  Reference Period  Value  Flag Codes Flags
# 0                   NaN               NaN  0.326         NaN   NaN
# 1                   NaN               NaN  0.337         NaN   NaN
# 2                   NaN               NaN  0.330         NaN   NaN
# 3                   NaN               NaN  0.325         NaN   NaN
# 4                   NaN               NaN  0.315         NaN   NaN
#
# [5 rows x 21 columns]

# %%
ocde_countries = df_ocde['LOCATION'].unique()
ocde_countries
# Out:
# array(['AUS', 'AUT', 'BEL', 'CAN', 'CZE', 'DNK', 'FIN', 'FRA', 'DEU',
#        'GRC', 'HUN', 'ISL', 'IRL', 'ITA', 'JPN', 'KOR', 'LUX', 'MEX',
#        'NLD', 'NZL', 'NOR', 'POL', 'PRT', 'SVK', 'ESP', 'SWE', 'CHE',
#        'TUR', 'GBR', 'USA', 'CHL', 'EST', 'ISR', 'RUS', 'SVN', 'LVA',
#        'LTU', 'BRA', 'CHN', 'CRI', 'IND', 'ZAF', 'BGR', 'ROU'],
#       dtype=object)

# %%
fig, ax = plt.subplots(1,1, figsize=(8,6))

for country in ocde_countries:
    df_country = df[(df['country_code'] == country) & (df['reporting_year'] >= 1990)]
    color = 'red' if country == 'CHL' else 'lightgray'
    df_country.plot(x='reporting_year', y='gini', color=color, ax=ax, legend=False)

# %%
fig, ax = plt.subplots(1,1, figsize=(8,6))

for country in ocde_countries:
    df_country = df[(df['country_code'] == country) & (df['reporting_year'] >= 1990)]
    color = 'red' if country == 'CHL' else 'lightgray'
    df_country.plot(x='reporting_gdp', y='gini', color=color, ax=ax, legend=False)

# %%
fig, ax = plt.subplots(1,1, figsize=(8,6)) 
xmin, xmax = 18, 85

for country in df_gini['Entity'].unique():
    df_country = df_gini[(df_gini['Entity'] == country)]
    x = df_country[df_country['Year'] == 2015]['Gini index of income in 1990 (inc. non-survey years)'].item()
    y = df_country[df_country['Year'] == 2015]['Gini index of income in 2015 (inc. non-survey years)'].item()
    if country == 'Chile':
        color = 'steelblue'
        alpha = 1.0
    elif df_country[df_country['Year'] == 2015]['Code'].item() in ocde_countries:
        color = 'orange'
        alpha = 0.5
    else:
        color = 'lightgray'
        alpha = 0.5
    ax.scatter(x, y, color=color, alpha=alpha)
    
ax.plot([xmin, xmax], [xmin, xmax], '--', color='#d2d2d2')
ax.set_xlim([xmin, xmax])
ax.set_ylim([22, 68])
plt.show()

# %% [markdown]
# ## Parte 4: Datos OCDE

# %%
df_ocde.head()
# Out:
#   LOCATION    Country MEASURE  \
# 0      AUS  Australia    GINI
# 1      AUS  Australia    GINI
# 2      AUS  Australia    GINI
# 3      AUS  Australia    GINI
# 4      AUS  Australia    GINI
#
#                                              Measure  AGE         Age group  \
# 0  Gini (disposable income, post taxes and transf...  TOT  Total population
# 1  Gini (disposable income, post taxes and transf...  TOT  Total population
# 2  Gini (disposable income, post taxes and transf...  TOT  Total population
# 3  Gini (disposable income, post taxes and transf...  TOT  Total population
# 4  Gini (disposable income, post taxes and transf...  TOT  Total population
#
#   DEFINITION          Definition   METHODO                       Methodology  \
# 0    CURRENT  Current definition  METH2012  New income definition since 2012
# 1    CURRENT  Current definition  METH2012  New income definition since 2012
# 2    CURRENT  Current definition  METH2012  New income definition since 2012
# 3    CURRENT  Current definition  METH2012  New income definition since 2012
# 4    CURRENT  Current definition  METH2011      Income definition until 2011
#
#    ...  Year  Unit Code       Unit PowerCode Code  PowerCode  \
# 0  ...  2012     0_TO_1  0-1 scale              0      Units
# 1  ...  2014     0_TO_1  0-1 scale              0      Units
# 2  ...  2016     0_TO_1  0-1 scale              0      Units
# 3  ...  2018     0_TO_1  0-1 scale              0      Units
# 4  ...  2004     0_TO_1  0-1 scale              0      Units
#
#   Reference Period Code  Reference Period  Value  Flag Codes Flags
# 0                   NaN               NaN  0.326         NaN   NaN
# 1                   NaN               NaN  0.337         NaN   NaN
# 2                   NaN               NaN  0.330         NaN   NaN
# 3                   NaN               NaN  0.325         NaN   NaN
# 4                   NaN               NaN  0.315         NaN   NaN
#
# [5 rows x 21 columns]

# %%
df_ocde.columns
# Out:
# Index(['LOCATION', 'Country', 'MEASURE', 'Measure', 'AGE', 'Age group',
#        'DEFINITION', 'Definition', 'METHODO', 'Methodology', 'TIME', 'Year',
#        'Unit Code', 'Unit', 'PowerCode Code', 'PowerCode',
#        'Reference Period Code', 'Reference Period', 'Value', 'Flag Codes',
#        'Flags'],
#       dtype='object')

# %%
df_ocde['METHODO'].unique()
# Out:
# array(['METH2012', 'METH2011'], dtype=object)

# %%
df_ocde['Measure'].unique()
# Out:
# array(['Gini (disposable income, post taxes and transfers)',
#        'Consumer Price Index (base 2010=100)',
#        'Age group 0-17: Poverty rate after taxes and transfers',
#        'Total earnings (current prices)',
#        'Income from self-employment (current prices)',
#        'Taxes and social security contributions paid directly by households (Current prices)',
#        'Age group 0-17: mean disposable income (current prices)',
#        'Age group 18-25: mean disposable income (current prices)',
#        'Capital income (current prices)',
#        'Age group 18-25: Poverty rate after taxes and transfers',
#        'Purchasing Power Parities for private consumption',
#        'Standard error Gini (post taxes and transfers)',
#        'Mean disposable income (current prices)',
#        'Gini (market income, before taxes and transfers)',
#        'Age group 26-40: Poverty rate after taxes and transfers',
#        'Income from self-employment and from goods produced for own consumption (current prices)',
#        'Capital and private transfers (current prices)',
#        'Current transfers paid by households to non-profit institutions and other households (Current prices)',
#        'Age group 26-40: mean disposable income (current prices)',
#        'Age group 41-50: mean disposable income (current prices)',
#        'Current transfers received (Current prices)',
#        'Age group 41-50: Poverty rate after taxes and transfers',
#        'Median disposable income (current prices)',
#        'Age group 51-65: Poverty rate after taxes and transfers',
#        'Current transfers paid (Current prices)',
#        'Age group 51-65: mean disposable income (current prices)',
#        'Age group 66-75: mean disposable income (current prices)',
#        'Age group 66-75: Poverty rate after taxes and transfers',
#        'Palma ratio',
#        'Age group 76+: Poverty rate after taxes and transfers',
#        'Age group 76+: mean disposable income (current prices)',
#        'All age groups: mean disposable income (current prices)',
#        'Poverty rate before taxes and transfers, Poverty line 50%',
#        'Poverty rate after taxes and transfers, Poverty line 50%',
#        'Mean Poverty gap after taxes and transfers, Poverty line 50%',
#        'Median Poverty gap after taxes and transfers, Poverty line 50%',
#        'All age groups: Poverty rate after taxes and transfers',
#        'Poverty rate before taxes and transfers, Poverty line 60%',
#        'Poverty rate after taxes and transfers, Poverty line 60%',
#        'Mean Poverty gap after taxes and transfers, Poverty line 60%',
#        'Median Poverty gap after taxes and transfers, Poverty line 60%',
#        'P90/P10 disposable income decile ratio',
#        'P90/P50  disposable income decile ratio',
#        'P50/P10  disposable income decile ratio',
#        'S80/S20 disposable income quintile share',
#        'Total number of individuals', 'Age group 0-17: share',
#        'Age group 18-25: share', 'Age group 26-40: share',
#        'Age group 41-50: share', 'Age group 51-65: share',
#        'Age group 66-75: share', 'Age group 76+: share',
#        'Total number of households',
#        'Income from own consumption (Current prices)',
#        'Contributions paid by households to employment-related social insurance schemes (Current prices)',
#        'All working-age household types: mean disposable income (current prices)',
#        'All  working-age household types: Poverty rate before taxes and transfers',
#        'All  working-age household types: Poverty rate after taxes and transfers',
#        'Consumer Price Index (base 2015=100)'], dtype=object)

# %%
fig, ax = plt.subplots(1,1, figsize=(8,6))

for country in ocde_countries:
    df_country = df_ocde[(df_ocde['LOCATION'] == country)
                         & (df_ocde['Year'] >= 1990)
                         & (df_ocde['Measure'] == 'Gini (disposable income, post taxes and transfers)')]
    color = 'red' if country == 'CHL' else 'lightgray'
    df_country.plot(x='Year', y='Value', color=color, ax=ax, legend=False, alpha=0.5)

# %%
df_country
# Out:
#       LOCATION  Country MEASURE  \
# 69457      ROU  Romania    GINI
# 69458      ROU  Romania    GINI
# 69459      ROU  Romania    GINI
# 69460      ROU  Romania    GINI
# 69461      ROU  Romania    GINI
# 69462      ROU  Romania    GINI
# 69463      ROU  Romania    GINI
# 69464      ROU  Romania    GINI
# 69465      ROU  Romania    GINI
# 69466      ROU  Romania    GINI
# 69467      ROU  Romania    GINI
# 69468      ROU  Romania    GINI
# 69469      ROU  Romania    GINI
# 69470      ROU  Romania    GINI
# 69555      ROU  Romania    GINI
# 69556      ROU  Romania    GINI
# 69557      ROU  Romania    GINI
# 69558      ROU  Romania    GINI
# 69559      ROU  Romania    GINI
# 69560      ROU  Romania    GINI
# 69561      ROU  Romania    GINI
# 69562      ROU  Romania    GINI
# 69563      ROU  Romania    GINI
# 69564      ROU  Romania    GINI
# 69565      ROU  Romania    GINI
# 69566      ROU  Romania    GINI
# 69567      ROU  Romania    GINI
# 69568      ROU  Romania    GINI
# 69765      ROU  Romania    GINI
# 69766      ROU  Romania    GINI
# 69767      ROU  Romania    GINI
# 69768      ROU  Romania    GINI
# 69769      ROU  Romania    GINI
# 69770      ROU  Romania    GINI
# 69771      ROU  Romania    GINI
# 69772      ROU  Romania    GINI
# 69773      ROU  Romania    GINI
# 69774      ROU  Romania    GINI
# 69775      ROU  Romania    GINI
# 69776      ROU  Romania    GINI
# 69777      ROU  Romania    GINI
# 69778      ROU  Romania    GINI
#
#                                                  Measure  AGE  \
# 69457  Gini (disposable income, post taxes and transf...  OLD
# 69458  Gini (disposable income, post taxes and transf...  OLD
# 69459  Gini (disposable income, post taxes and transf...  OLD
# 69460  Gini (disposable income, post taxes and transf...  OLD
# 69461  Gini (disposable income, post taxes and transf...  OLD
# 69462  Gini (disposable income, post taxes and transf...  OLD
# 69463  Gini (disposable income, post taxes and transf...  OLD
# 69464  Gini (disposable income, post taxes and transf...  OLD
# 69465  Gini (disposable income, post taxes and transf...  OLD
# 69466  Gini (disposable income, post taxes and transf...  OLD
# 69467  Gini (disposable income, post taxes and transf...  OLD
# 69468  Gini (disposable income, post taxes and transf...  OLD
# 69469  Gini (disposable income, post taxes and transf...  OLD
# 69470  Gini (disposable income, post taxes and transf...  OLD
# 69555  Gini (disposable income, post taxes and transf...  TOT
# 69556  Gini (disposable income, post taxes and transf...  TOT
# 69557  Gini (disposable income, post taxes and transf...  TOT
# 69558  Gini (disposable income, post taxes and transf...  TOT
# 69559  Gini (disposable income, post taxes and transf...  TOT
# 69560  Gini (disposable income, post taxes and transf...  TOT
# 69561  Gini (disposable income, post taxes and transf...  TOT
# 69562  Gini (disposable income, post taxes and transf...  TOT
# 69563  Gini (disposable income, post taxes and transf...  TOT
# 69564  Gini (disposable income, post taxes and transf...  TOT
# 69565  Gini (disposable income, post taxes and transf...  TOT
# 69566  Gini (disposable income, post taxes and transf...  TOT
# 69567  Gini (disposable income, post taxes and transf...  TOT
# 69568  Gini (disposable income, post taxes and transf...  TOT
# 69765  Gini (disposable income, post taxes and transf...   WA
# 69766  Gini (disposable income, post taxes and transf...   WA
# 69767  Gini (disposable income, post taxes and transf...   WA
# 69768  Gini (disposable income, post taxes and transf...   WA
# 69769  Gini (disposable income, post taxes and transf...   WA
# 69770  Gini (disposable income, post taxes and transf...   WA
# 69771  Gini (disposable income, post taxes and transf...   WA
# 69772  Gini (disposable income, post taxes and transf...   WA
# 69773  Gini (disposable income, post taxes and transf...   WA
# 69774  Gini (disposable income, post taxes and transf...   WA
# 69775  Gini (disposable income, post taxes and transf...   WA
# 69776  Gini (disposable income, post taxes and transf...   WA
# 69777  Gini (disposable income, post taxes and transf...   WA
# 69778  Gini (disposable income, post taxes and transf...   WA
#
#                                  Age group DEFINITION          Definition  \
# 69457  Retirement age population: above 65    CURRENT  Current definition
# 69458  Retirement age population: above 65    CURRENT  Current definition
# 69459  Retirement age population: above 65    CURRENT  Current definition
# 69460  Retirement age population: above 65    CURRENT  Current definition
# 69461  Retirement age population: above 65    CURRENT  Current definition
# 69462  Retirement age population: above 65    CURRENT  Current definition
# 69463  Retirement age population: above 65    CURRENT  Current definition
# 69464  Retirement age population: above 65    CURRENT  Current definition
# 69465  Retirement age population: above 65    CURRENT  Current definition
# 69466  Retirement age population: above 65    CURRENT  Current definition
# 69467  Retirement age population: above 65    CURRENT  Current definition
# 69468  Retirement age population: above 65    CURRENT  Current definition
# 69469  Retirement age population: above 65    CURRENT  Current definition
# 69470  Retirement age population: above 65    CURRENT  Current definition
# 69555                     Total population    CURRENT  Current definition
# 69556                     Total population    CURRENT  Current definition
# 69557                     Total population    CURRENT  Current definition
# 69558                     Total population    CURRENT  Current definition
# 69559                     Total population    CURRENT  Current definition
# 69560                     Total population    CURRENT  Current definition
# 69561                     Total population    CURRENT  Current definition
# 69562                     Total population    CURRENT  Current definition
# 69563                     Total population    CURRENT  Current definition
# 69564                     Total population    CURRENT  Current definition
# 69565                     Total population    CURRENT  Current definition
# 69566                     Total population    CURRENT  Current definition
# 69567                     Total population    CURRENT  Current definition
# 69568                     Total population    CURRENT  Current definition
# 69765        Working age population: 18-65    CURRENT  Current definition
# 69766        Working age population: 18-65    CURRENT  Current definition
# 69767        Working age population: 18-65    CURRENT  Current definition
# 69768        Working age population: 18-65    CURRENT  Current definition
# 69769        Working age population: 18-65    CURRENT  Current definition
# 69770        Working age population: 18-65    CURRENT  Current definition
# 69771        Working age population: 18-65    CURRENT  Current definition
# 69772        Working age population: 18-65    CURRENT  Current definition
# 69773        Working age population: 18-65    CURRENT  Current definition
# 69774        Working age population: 18-65    CURRENT  Current definition
# 69775        Working age population: 18-65    CURRENT  Current definition
# 69776        Working age population: 18-65    CURRENT  Current definition
# 69777        Working age population: 18-65    CURRENT  Current definition
# 69778        Working age population: 18-65    CURRENT  Current definition
#
#         METHODO                       Methodology  ...  Year  Unit Code  \
# 69457  METH2012  New income definition since 2012  ...  2006     0_TO_1
# 69458  METH2012  New income definition since 2012  ...  2007     0_TO_1
# 69459  METH2012  New income definition since 2012  ...  2008     0_TO_1
# 69460  METH2012  New income definition since 2012  ...  2009     0_TO_1
# 69461  METH2012  New income definition since 2012  ...  2010     0_TO_1
# 69462  METH2012  New income definition since 2012  ...  2011     0_TO_1
# 69463  METH2012  New income definition since 2012  ...  2012     0_TO_1
# 69464  METH2012  New income definition since 2012  ...  2013     0_TO_1
# 69465  METH2012  New income definition since 2012  ...  2014     0_TO_1
# 69466  METH2012  New income definition since 2012  ...  2015     0_TO_1
# 69467  METH2012  New income definition since 2012  ...  2016     0_TO_1
# 69468  METH2012  New income definition since 2012  ...  2017     0_TO_1
# 69469  METH2012  New income definition since 2012  ...  2018     0_TO_1
# 69470  METH2012  New income definition since 2012  ...  2019     0_TO_1
# 69555  METH2012  New income definition since 2012  ...  2006     0_TO_1
# 69556  METH2012  New income definition since 2012  ...  2007     0_TO_1
# 69557  METH2012  New income definition since 2012  ...  2008     0_TO_1
# 69558  METH2012  New income definition since 2012  ...  2009     0_TO_1
# 69559  METH2012  New income definition since 2012  ...  2010     0_TO_1
# 69560  METH2012  New income definition since 2012  ...  2011     0_TO_1
# 69561  METH2012  New income definition since 2012  ...  2012     0_TO_1
# 69562  METH2012  New income definition since 2012  ...  2013     0_TO_1
# 69563  METH2012  New income definition since 2012  ...  2014     0_TO_1
# 69564  METH2012  New income definition since 2012  ...  2015     0_TO_1
# 69565  METH2012  New income definition since 2012  ...  2016     0_TO_1
# 69566  METH2012  New income definition since 2012  ...  2017     0_TO_1
# 69567  METH2012  New income definition since 2012  ...  2018     0_TO_1
# 69568  METH2012  New income definition since 2012  ...  2019     0_TO_1
# 69765  METH2012  New income definition since 2012  ...  2006     0_TO_1
# 69766  METH2012  New income definition since 2012  ...  2007     0_TO_1
# 69767  METH2012  New income definition since 2012  ...  2008     0_TO_1
# 69768  METH2012  New income definition since 2012  ...  2009     0_TO_1
# 69769  METH2012  New income definition since 2012  ...  2010     0_TO_1
# 69770  METH2012  New income definition since 2012  ...  2011     0_TO_1
# 69771  METH2012  New income definition since 2012  ...  2012     0_TO_1
# 69772  METH2012  New income definition since 2012  ...  2013     0_TO_1
# 69773  METH2012  New income definition since 2012  ...  2014     0_TO_1
# 69774  METH2012  New income definition since 2012  ...  2015     0_TO_1
# 69775  METH2012  New income definition since 2012  ...  2016     0_TO_1
# 69776  METH2012  New income definition since 2012  ...  2017     0_TO_1
# 69777  METH2012  New income definition since 2012  ...  2018     0_TO_1
# 69778  METH2012  New income definition since 2012  ...  2019     0_TO_1
#
#             Unit PowerCode Code  PowerCode Reference Period Code  \
# 69457  0-1 scale              0      Units                   NaN
# 69458  0-1 scale              0      Units                   NaN
# 69459  0-1 scale              0      Units                   NaN
# 69460  0-1 scale              0      Units                   NaN
# 69461  0-1 scale              0      Units                   NaN
# 69462  0-1 scale              0      Units                   NaN
# 69463  0-1 scale              0      Units                   NaN
# 69464  0-1 scale              0      Units                   NaN
# 69465  0-1 scale              0      Units                   NaN
# 69466  0-1 scale              0      Units                   NaN
# 69467  0-1 scale              0      Units                   NaN
# 69468  0-1 scale              0      Units                   NaN
# 69469  0-1 scale              0      Units                   NaN
# 69470  0-1 scale              0      Units                   NaN
# 69555  0-1 scale              0      Units                   NaN
# 69556  0-1 scale              0      Units                   NaN
# 69557  0-1 scale              0      Units                   NaN
# 69558  0-1 scale              0      Units                   NaN
# 69559  0-1 scale              0      Units                   NaN
# 69560  0-1 scale              0      Units                   NaN
# 69561  0-1 scale              0      Units                   NaN
# 69562  0-1 scale              0      Units                   NaN
# 69563  0-1 scale              0      Units                   NaN
# 69564  0-1 scale              0      Units                   NaN
# 69565  0-1 scale              0      Units                   NaN
# 69566  0-1 scale              0      Units                   NaN
# 69567  0-1 scale              0      Units                   NaN
# 69568  0-1 scale              0      Units                   NaN
# 69765  0-1 scale              0      Units                   NaN
# 69766  0-1 scale              0      Units                   NaN
# 69767  0-1 scale              0      Units                   NaN
# 69768  0-1 scale              0      Units                   NaN
# 69769  0-1 scale              0      Units                   NaN
# 69770  0-1 scale              0      Units                   NaN
# 69771  0-1 scale              0      Units                   NaN
# 69772  0-1 scale              0      Units                   NaN
# 69773  0-1 scale              0      Units                   NaN
# 69774  0-1 scale              0      Units                   NaN
# 69775  0-1 scale              0      Units                   NaN
# 69776  0-1 scale              0      Units                   NaN
# 69777  0-1 scale              0      Units                   NaN
# 69778  0-1 scale              0      Units                   NaN
#
#        Reference Period  Value  Flag Codes Flags
# 69457               NaN  0.344         NaN   NaN
# 69458               NaN  0.321         NaN   NaN
# 69459               NaN  0.302         NaN   NaN
# 69460               NaN  0.290         NaN   NaN
# 69461               NaN  0.293         NaN   NaN
# 69462               NaN  0.298         NaN   NaN
# 69463               NaN  0.307         NaN   NaN
# 69464               NaN  0.319         NaN   NaN
# 69465               NaN  0.383         NaN   NaN
# 69466               NaN  0.295         NaN   NaN
# 69467               NaN  0.297         NaN   NaN
# 69468               NaN  0.305         NaN   NaN
# 69469               NaN  0.303         NaN   NaN
# 69470               NaN  0.306         NaN   NaN
# 69555               NaN  0.380         NaN   NaN
# 69556               NaN  0.360         NaN   NaN
# 69557               NaN  0.349         NaN   NaN
# 69558               NaN  0.333         NaN   NaN
# 69559               NaN  0.339         NaN   NaN
# 69560               NaN  0.339         NaN   NaN
# 69561               NaN  0.344         NaN   NaN
# 69562               NaN  0.347         NaN   NaN
# 69563               NaN  0.371         NaN   NaN
# 69564               NaN  0.346         NaN   NaN
# 69565               NaN  0.332         NaN   NaN
# 69566               NaN  0.351         NaN   NaN
# 69567               NaN  0.350         NaN   NaN
# 69568               NaN  0.339         NaN   NaN
# 69765               NaN  0.371         NaN   NaN
# 69766               NaN  0.354         NaN   NaN
# 69767               NaN  0.345         NaN   NaN
# 69768               NaN  0.332         NaN   NaN
# 69769               NaN  0.337         NaN   NaN
# 69770               NaN  0.340         NaN   NaN
# 69771               NaN  0.342         NaN   NaN
# 69772               NaN  0.344         NaN   NaN
# 69773               NaN  0.362         NaN   NaN
# 69774               NaN  0.343         NaN   NaN
# 69775               NaN  0.328         NaN   NaN
# 69776               NaN  0.347         NaN   NaN
# 69777               NaN  0.346         NaN   NaN
# 69778               NaN  0.335         NaN   NaN
#
# [42 rows x 21 columns]

# %%
fig, ax = plt.subplots(1,1, figsize=(8,6))

for country in ocde_countries:
# for country in ['CHL']:

    df_country = df_ocde[(df_ocde['LOCATION'] == country)
                         & (df_ocde['Year'] >= 1990)
                         & (df_ocde['Measure'] == 'Gini (disposable income, post taxes and transfers)')
                         & (df_ocde['AGE'] == 'TOT')
                         & (df_ocde['METHODO'] == 'METH2012')]
    color = 'red' if country == 'CHL' else 'lightgray'
    df_country.plot(x='Year', y='Value', color=color, ax=ax, legend=False, alpha=0.5)

# %%
fig, ax = plt.subplots(1,1, figsize=(8,6))

for idx_country, country in enumerate(ocde_countries):

    df_after = df_ocde[(df_ocde['LOCATION'] == country)
                         & (df_ocde['Year'] >= 1990)
                         & (df_ocde['Measure'] == 'Gini (disposable income, post taxes and transfers)')
                         & (df_ocde['AGE'] == 'TOT')
                         & (df_ocde['METHODO'] == 'METH2012')]
    value_after = df_after.iloc[-1]['Value']
    
    df_before = df_ocde[(df_ocde['LOCATION'] == country)
                         & (df_ocde['Year'] >= 1990)
                         & (df_ocde['Measure'] == 'Gini (market income, before taxes and transfers)')
                         & (df_ocde['AGE'] == 'TOT')
                         & (df_ocde['METHODO'] == 'METH2012')]
    value_before = df_before.iloc[-1]['Value']
    
    color = 'red' if country == 'CHL' else 'lightgray'
    
    ax.hlines(idx_country, value_before, value_after, colors=[color], alpha=0.5)
    ax.scatter([value_before], [idx_country], color="steelblue")
    ax.scatter([value_after], [idx_country], color="orange")

# %%
countries = []
before = []
after = []

df = pd.DataFrame()

for idx_country, country in enumerate(ocde_countries):
    
    countries.append(country)

    df_after = df_ocde[(df_ocde['LOCATION'] == country)
                         & (df_ocde['Year'] >= 1990)
                         & (df_ocde['Measure'] == 'Gini (disposable income, post taxes and transfers)')
                         & (df_ocde['AGE'] == 'TOT')
                         & (df_ocde['METHODO'] == 'METH2012')]
    after.append(df_after.iloc[-1]['Value'])
    
    df_before = df_ocde[(df_ocde['LOCATION'] == country)
                         & (df_ocde['Year'] >= 1990)
                         & (df_ocde['Measure'] == 'Gini (market income, before taxes and transfers)')
                         & (df_ocde['AGE'] == 'TOT')
                         & (df_ocde['METHODO'] == 'METH2012')]
    before.append(df_before.iloc[-1]['Value'])
    
df['country'] = countries
df['before'] = before
df['after'] = after
df['gap'] = df['before'] - df['after']

df.head()
# Out:
#   country  before  after    gap
# 0     AUS   0.454  0.325  0.129
# 1     AUT   0.486  0.274  0.212
# 2     BEL   0.489  0.262  0.227
# 3     CAN   0.421  0.301  0.120
# 4     CZE   0.432  0.248  0.184

# %%
by_after = df.sort_values('after').reset_index()
by_gap = df.sort_values('gap', ascending=False).reset_index()

# %%
def plot_gini(df, ax):
    
    for idx_row, row in df.iterrows():
        
        color = 'red' if row['country'] == 'CHL' else 'lightgray'

        value_before = row['before']
        value_after = row['after']
        ax.hlines(idx_row, value_before, value_after, colors=[color], alpha=0.5)
        ax.scatter([value_before], [idx_row], color="steelblue")
        ax.scatter([value_after], [idx_row], color="orange")
    
    
fig, ax = plt.subplots(1,2,figsize=(12,6))
plot_gini(by_after, ax[0])
plot_gini(by_gap, ax[1])

plt.show()

# %% [markdown]
# ## Parte 5: Distribución de ingresos

# %%
fig, ax = plt.subplots(1,1, figsize=(8,6))

for country in ocde_countries:

    df_country = df_ocde[(df_ocde['LOCATION'] == country)
                         & (df_ocde['Year'] >= 1990)
                         & (df_ocde['Measure'] == 'P90/P10 disposable income decile ratio')
                         & (df_ocde['AGE'] == 'TOT')
                         & (df_ocde['METHODO'] == 'METH2012')]
    color = 'red' if country == 'CHL' else 'lightgray'
    df_country.plot(x='Year', y='Value', color=color, ax=ax, legend=False, alpha=0.5)

# %%
years = []
decile_distribution = {}
deciles = [x for x in df_chile.columns if 'decile' in x]
for decile in deciles:
    decile_distribution[decile] = []

for idx, row in df_chile.iterrows():
    years.append(row['reporting_year'])
    for decile in deciles:
        decile_distribution[decile].append(row[decile])

# %%
decile_distribution
# Out:
# {'decile1': [0.0116019492355596,
#   0.0118553955273044,
#   0.0143104217527041,
#   0.0122909713183081,
#   0.0133235354985257,
#   0.0125389539604489,
#   0.013084670194383,
#   0.0138081354912954,
#   0.0185468893648728,
#   0.019279423863461,
#   0.0205096688050581,
#   0.0214351527227739,
#   0.0223997074876653,
#   0.0226161399622648,
#   0.020621702524623],
#  'decile2': [0.0218358060539591,
#   0.021696968760948,
#   0.0241730402998276,
#   0.0223053614724533,
#   0.0231710301933902,
#   0.0225651331076592,
#   0.0252069888982955,
#   0.0262896764215879,
#   0.0310919011184767,
#   0.0323946965708239,
#   0.0329379434330706,
#   0.0337441146929893,
#   0.0350143089439125,
#   0.0350338370540364,
#   0.0341261530692532],
#  'decile3': [0.0294248948050559,
#   0.0289412320735623,
#   0.0319152438977235,
#   0.0297331369176112,
#   0.0311599028026939,
#   0.0304616985626497,
#   0.0339971852667012,
#   0.0351048674447191,
#   0.0401613315077447,
#   0.0410012838477892,
#   0.0418370544537457,
#   0.0421283871355779,
#   0.0439962762359756,
#   0.0440363767266668,
#   0.0431301088897192],
#  'decile4': [0.0376034393132926,
#   0.0367476297433231,
#   0.0397593240488367,
#   0.03755984339211,
#   0.0393679984694875,
#   0.0389069340072079,
#   0.0427383748056512,
#   0.0443867580750396,
#   0.049118228175563,
#   0.0497468496748836,
#   0.05090878590674,
#   0.0508106269532102,
#   0.0527407713941331,
#   0.0527384087985305,
#   0.0519533319047078],
#  'decile5': [0.0470670832578049,
#   0.0457218325086556,
#   0.0489121254012566,
#   0.0469859758212527,
#   0.0488056787199036,
#   0.0482889301164363,
#   0.05277258018708,
#   0.0548695742602043,
#   0.0592912309123516,
#   0.0594621036910394,
#   0.0602586814000542,
#   0.0603890925565171,
#   0.0621021549556723,
#   0.0622955722194321,
#   0.0614081120296403],
#  'decile6': [0.0591246804523411,
#   0.0574520263931939,
#   0.0608809426142373,
#   0.0588858296931906,
#   0.0609391024810913,
#   0.0602476583507698,
#   0.0651950393165597,
#   0.0672988324497242,
#   0.0711273043225895,
#   0.0708375008972582,
#   0.071316153838117,
#   0.0714905790101382,
#   0.0734339360145892,
#   0.0734727805527086,
#   0.0731361720554902],
#  'decile7': [0.0761779844810059,
#   0.0737932666475414,
#   0.0772169816215154,
#   0.0752820961827896,
#   0.0778187526585076,
#   0.0768131426496824,
#   0.0809602587996505,
#   0.0832968496336638,
#   0.0864063063911847,
#   0.085488421210527,
#   0.0866508084538248,
#   0.0858111078145008,
#   0.0881478924972677,
#   0.0878599780025887,
#   0.0879017370387365],
#  'decile8': [0.1031754857484735,
#   0.0991904398961526,
#   0.1014462742635413,
#   0.1019883548520254,
#   0.1044526042406575,
#   0.1033848795109306,
#   0.1059643622204776,
#   0.1073014821899936,
#   0.1097620011086948,
#   0.107737850279561,
#   0.1091910149452813,
#   0.107795209377079,
#   0.1100374746377436,
#   0.1089880181210324,
#   0.1113317789415875],
#  'decile9': [0.1600749868907423,
#   0.1540960904795343,
#   0.149426998458542,
#   0.155901330399394,
#   0.1566874128942395,
#   0.1570745628226109,
#   0.1542616247048011,
#   0.154101205416714,
#   0.1555614083290216,
#   0.1518569916685877,
#   0.15345921768041,
#   0.1526604842330117,
#   0.1515417680581548,
#   0.1495398535147739,
#   0.1584164350213],
#  'decile10': [0.4539136897617596,
#   0.4705051179697842,
#   0.4519586476418106,
#   0.4590670999508522,
#   0.4442739820414971,
#   0.4497181069115916,
#   0.4258189156064063,
#   0.4135426186170574,
#   0.3789333987695106,
#   0.3821948782960448,
#   0.3729306710836895,
#   0.3737352455042145,
#   0.3605857097748791,
#   0.3634190350479563,
#   0.35797446852493]}

# %%
fig, ax = plt.subplots()
ax.stackplot(years, decile_distribution.values(),
             labels=decile_distribution.keys(),
             alpha=0.8)
# ax.legend(loc='upper left')

ax.set_xlim(1987, 2020)
ax.set_ylim(0, 1)

plt.show()

# %% [markdown]
# ## Parte 6: Otros puntos de vista

# %% [markdown]
# [estos](https://twitter.com/cristobalotero/status/1192150305871253505) [dos](https://twitter.com/_Ignacio_Flores/status/1573179884020662275) hilos de Twitter

# %% [markdown]
# [World Inequality Database](https://wid.world)
