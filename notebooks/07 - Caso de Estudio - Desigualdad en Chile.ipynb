# %% [markdown]
# # Clase 07 - Caso de Estudio: Desigualdad en Chile

# %% [markdown]
# Profesor: **Fernando Becerra**, f.becerra@udd.cl, [www.fernandobecerra.com](www.fernandobecerra.com)

# %% [markdown]
# ##### Contexto
#
# [Discurso del presidente Boric en las Nacionaes Unidas](https://www.youtube.com/watch?v=EfTYTHtspeQ): "Nos duele ser uno de los países más desiguales del mundo"
#
# [Respuesta](https://www.latercera.com/opinion/noticia/es-chile-el-pais-mas-desigual-del-mundo/XYBKEGBTPBE3RB5NATYT4RNLSE/): "A partir de la última información disponible del Banco Mundial, en la región Colombia tiene un coeficiente de Gini de 54,2 (mayor el número es más desigual), Panamá (49,8), Costa Rica (49,3), Brasil (48,9), Guatemala (48,3), Honduras (48,2), Ecuador (47,3), Nicaragua (46,2), México (45,4), mientras Chile un 44,9."
#
# Discusión en Twitter: [baja del Gini a través de los años](https://twitter.com/ignaciobriones_/status/1572957052846346240), [trayectoria del Gini vs GDP](https://twitter.com/OLanderretche/status/1574571809466458113) ([inspiración](http://i0.wp.com/michelbaudin.com/wp-content/uploads/2013/05/brazil-gini-versus-gdp-chart.jpg))
#
# Aquí hay un problema en [cómo se comunican estos datos](https://www.latercera.com/opinion/noticia/comunicar-las-cifras/VUNEVNAPMJFOBPZK4WSFUCSEKQ/).
#
#
# ##### Objetivo
# Hacer nuestro propio análisis más serio basado en la visualización y encontrar una historia que contar
#
# Inspiración: [Our World in Data](https://ourworldindata.org/income-inequality)

# %% [markdown]
# Lo primero es lo primero: importar lo típico

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# [World Bank](https://pip.worldbank.org/poverty-calculator)

# %%
df = pd.read_csv('../data/desigualdad/pip.csv')
df.head()
# Out:
#              region_name region_code country_name country_code  \
# 0     Sub-Saharan Africa         SSA       Angola          AGO
# 1     Sub-Saharan Africa         SSA       Angola          AGO
# 2     Sub-Saharan Africa         SSA       Angola          AGO
# 3  Europe & Central Asia         ECA      Albania          ALB
# 4  Europe & Central Asia         ECA      Albania          ALB
#
#    reporting_year reporting_level survey_acronym survey_coverage  survey_year  \
# 0            2000        national            HBS        national      2000.21
# 1            2008        national      IBEP-MICS        national      2008.50
# 2            2018        national          IDREA        national      2018.17
# 3            1996        national            EWS        national      1996.00
# 4            2002        national           LSMS        national      2002.00
#
#   welfare_type  ...   decile9  decile10       cpi         ppp  reporting_pop  \
# 0  consumption  ...  0.158687  0.402455  0.014200  107.269989       16395477
# 1  consumption  ...  0.162333  0.323117  0.303449  107.269989       21695636
# 2  consumption  ...  0.159390  0.396244  1.231024  107.269989       30809787
# 3  consumption  ...  0.148995  0.212156  0.399635   50.357372        3168033
# 4  consumption  ...  0.149251  0.254356  0.701637   50.357372        3051010
#
#    reporting_gdp  reporting_pce  is_interpolated  distribution_type  \
# 0    2451.509826            NaN            False              micro
# 1    4077.776844    1620.065607            False              micro
# 2    3595.106667    2093.495848            False              micro
# 3    1633.551572    1714.813416            False              micro
# 4    2247.497491    1685.368128            False              micro
#
#    estimation_type
# 0           survey
# 1           survey
# 2           survey
# 3           survey
# 4           survey
#
# [5 rows x 40 columns]

# %%
list(df.columns)
# Out:
# ['region_name',
#  'region_code',
#  'country_name',
#  'country_code',
#  'reporting_year',
#  'reporting_level',
#  'survey_acronym',
#  'survey_coverage',
#  'survey_year',
#  'welfare_type',
#  'survey_comparability',
#  'comparable_spell',
#  'poverty_line',
#  'headcount',
#  'poverty_gap',
#  'poverty_severity',
#  'watts',
#  'mean',
#  'median',
#  'mld',
#  'gini',
#  'polarization',
#  'decile1',
#  'decile2',
#  'decile3',
#  'decile4',
#  'decile5',
#  'decile6',
#  'decile7',
#  'decile8',
#  'decile9',
#  'decile10',
#  'cpi',
#  'ppp',
#  'reporting_pop',
#  'reporting_gdp',
#  'reporting_pce',
#  'is_interpolated',
#  'distribution_type',
#  'estimation_type']

# %%
df_chile = df[df['country_name'] == 'Chile']
df_chile.head()
# Out:
#                    region_name region_code country_name country_code  \
# 322  Latin America & Caribbean         LAC        Chile          CHL
# 323  Latin America & Caribbean         LAC        Chile          CHL
# 324  Latin America & Caribbean         LAC        Chile          CHL
# 325  Latin America & Caribbean         LAC        Chile          CHL
# 326  Latin America & Caribbean         LAC        Chile          CHL
#
#      reporting_year reporting_level survey_acronym survey_coverage  \
# 322            1987        national          CASEN        national
# 323            1990        national          CASEN        national
# 324            1992        national          CASEN        national
# 325            1994        national          CASEN        national
# 326            1996        national          CASEN        national
#
#      survey_year welfare_type  ...   decile9  decile10       cpi         ppp  \
# 322       1987.0       income  ...  0.160075  0.453914  0.141201  478.995697
# 323       1990.0       income  ...  0.154096  0.470505  0.265681  478.995697
# 324       1992.0       income  ...  0.149427  0.451959  0.356878  478.995697
# 325       1994.0       income  ...  0.155901  0.459067  0.435449  478.995697
# 326       1996.0       income  ...  0.156687  0.444274  0.501988  478.995697
#
#      reporting_pop  reporting_gdp  reporting_pce  is_interpolated  \
# 322       12642917    4710.709892    2400.793312            False
# 323       13274617    5470.479736    2754.646852            False
# 324       13719818    6343.227129    3301.817823            False
# 325       14166346    6877.434435    3716.155714            False
# 326       14587367    7770.539111    4336.964275            False
#
#      distribution_type  estimation_type
# 322              micro           survey
# 323              micro           survey
# 324              micro           survey
# 325              micro           survey
# 326              micro           survey
#
# [5 rows x 40 columns]

# %%
df_chile.plot(x='reporting_year', y='gini')
# Out:
# <AxesSubplot:xlabel='reporting_year'>

# %%
df_chile.plot(x='reporting_gdp', y='gini')
# Out:
# <AxesSubplot:xlabel='reporting_gdp'>

# %% [markdown]
# ## Parte 2: Contexto latinamerico

# %%
df_lac = df[df['region_code'] == 'LAC']
df_lac.head()
# Out:
#                   region_name region_code country_name country_code  \
# 19  Latin America & Caribbean         LAC    Argentina          ARG
# 20  Latin America & Caribbean         LAC    Argentina          ARG
# 21  Latin America & Caribbean         LAC    Argentina          ARG
# 22  Latin America & Caribbean         LAC    Argentina          ARG
# 23  Latin America & Caribbean         LAC    Argentina          ARG
#
#     reporting_year reporting_level survey_acronym survey_coverage  \
# 19            1980           urban            EPH           urban
# 20            1986           urban            EPH           urban
# 21            1987           urban            EPH           urban
# 22            1991           urban            EPH           urban
# 23            1992           urban            EPH           urban
#
#     survey_year welfare_type  ...   decile9  decile10         cpi       ppp  \
# 19       1980.0       income  ...  0.163836  0.301754    0.054894  10.80794
# 20       1986.0       income  ...  0.163225  0.322081    0.014070  10.80794
# 21       1987.0       income  ...  0.163314  0.342519    0.032549  10.80794
# 22       1991.0       income  ...  0.159374  0.366093  328.909183  10.80794
# 23       1992.0       income  ...  0.165745  0.342871    0.038808  10.80794
#
#     reporting_pop  reporting_gdp  reporting_pce  is_interpolated  \
# 19       23122598   10318.182985            NaN            False
# 20       26230730    9412.994813            NaN            False
# 21       26769634    9517.108610            NaN            False
# 22       28887231    8769.750400            NaN            False
# 23       29352237    9338.699517            NaN            False
#
#     distribution_type  estimation_type
# 19              group           survey
# 20              micro           survey
# 21              micro           survey
# 22              micro           survey
# 23              micro           survey
#
# [5 rows x 40 columns]

# %%
lac_countries = df_lac['country_name'].unique()
lac_countries
# Out:
# array(['Argentina', 'Belize', 'Bolivia', 'Brazil', 'Chile', 'Colombia',
#        'Costa Rica', 'Dominican Republic', 'Ecuador', 'Guatemala',
#        'Guyana', 'Honduras', 'Haiti', 'Jamaica', 'St. Lucia', 'Mexico',
#        'Nicaragua', 'Panama', 'Peru', 'Paraguay', 'El Salvador',
#        'Suriname', 'Trinidad and Tobago', 'Uruguay', 'Venezuela, RB'],
#       dtype=object)

# %%
fig, ax = plt.subplots(1,1, figsize=(8,6))

for country in lac_countries:
    df_country = df_lac[df_lac['country_name'] == country]
    color = 'red' if country == 'Chile' else 'lightgray'
    df_country.plot(x='reporting_year', y='gini', color=color, ax=ax, legend=False)

# %%
countries = ['Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia',
       'Costa Rica', 'Dominican Republic', 'Ecuador', 'Guatemala', 'Honduras', 'Mexico',
       'Nicaragua', 'Panama', 'Peru', 'Paraguay', 'El Salvador', 'Uruguay', 'Venezuela, RB']

fig, ax = plt.subplots(1,1, figsize=(8,6))

for country in countries:
    df_country = df_lac[(df_lac['country_name'] == country) & (df_lac['reporting_year'] >= 1990)]
    color = 'red' if country == 'Chile' else 'lightgray'
    df_country.plot(x='reporting_year', y='gini', color=color, ax=ax, legend=False)
    
plt.show()

# %%
countries = ['Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia',
       'Costa Rica', 'Dominican Republic', 'Ecuador', 'Guatemala', 'Honduras', 'Mexico',
       'Nicaragua', 'Panama', 'Peru', 'Paraguay', 'El Salvador', 'Uruguay', 'Venezuela, RB']

fig, ax = plt.subplots(1,1, figsize=(8,6))

for country in countries:
    df_country = df_lac[(df_lac['country_name'] == country) & (df_lac['reporting_year'] >= 1990)]
    color = 'red' if country == 'Chile' else 'lightgray'
    df_country.plot(x='reporting_gdp', y='gini', color=color, ax=ax, legend=False)
    
plt.show()

# %% [markdown]
# [OWID data](https://ourworldindata.org/grapher/gini-index-of-income-in-2015-vs-1990-gcip-including-non-survey-years)

# %%
df_gini = pd.read_csv("../data/desigualdad/gini-index-of-income-in-2015-vs-1990-gcip-including-non-survey-years.csv")
df_gini.head()
# Out:
#         Entity Code   Year  \
# 0  Afghanistan  AFG   2015
# 1  Afghanistan  AFG -10000
# 2  Afghanistan  AFG  -9000
# 3  Afghanistan  AFG  -8000
# 4  Afghanistan  AFG  -7000
#
#    Gini index of income in 2015 (inc. non-survey years)  \
# 0                                           36.81118
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Gini index of income in 1990 (inc. non-survey years)  \
# 0                                           36.81118
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Population (historical estimates)                 Country grouping
# 0                           33753500  Eastern Europe and Central Asia
# 1                              14737                              NaN
# 2                              20405                              NaN
# 3                              28253                              NaN
# 4                              39120                              NaN

# %%
df_gini['Country grouping'].unique()
# Out:
# array(['Eastern Europe and Central Asia', nan,
#        'Middle East and North Africa', 'Sub-Saharan Africa',
#        'Latin America and Caribbean', 'Advanced industrial economies',
#        'South Asia', 'East Asia and Pacific'], dtype=object)

# %%
fig, ax = plt.subplots(1,1, figsize=(8,6)) 

xmin, xmax = 18, 86

for country in df_gini['Entity'].unique():
    df_country = df_gini[df_gini['Entity'] == country]
    df_2015 = df_country[df_country['Year'] == 2015]
    x = df_2015['Gini index of income in 1990 (inc. non-survey years)'].item()
    y = df_2015['Gini index of income in 2015 (inc. non-survey years)'].item()
    
    if country == 'Chile':
        color = 'steelblue'
        alpha = 1.0
    elif df_2015['Country grouping'].item() == 'Latin America and Caribbean':
        color = 'orange'
        alpha = 0.5
    
    else:
        color = 'lightgray'
        alpha = 0.5
    
    ax.scatter(x, y, color=color, alpha=alpha)
    
    
ax.plot([xmin, xmax], [xmin, xmax], '--', color="#d2d2d2")
ax.set_xlim([xmin, xmax])
ax.set_ylim([22, 68])
plt.show()

# %% [markdown]
# ## Parte 3: Perros grandes

# %% [markdown]
# [datos OCDE](https://stats.oecd.org/Index.aspx?DataSetCode=IDD)

# %%
df_ocde = pd.read_csv('../data/desigualdad/IDD_30092022043102297.csv')
df_ocde.head()
# Out:
#   LOCATION    Country MEASURE  \
# 0      AUS  Australia    GINI
# 1      AUS  Australia    GINI
# 2      AUS  Australia    GINI
# 3      AUS  Australia    GINI
# 4      AUS  Australia    GINI
#
#                                              Measure  AGE         Age group  \
# 0  Gini (disposable income, post taxes and transf...  TOT  Total population
# 1  Gini (disposable income, post taxes and transf...  TOT  Total population
# 2  Gini (disposable income, post taxes and transf...  TOT  Total population
# 3  Gini (disposable income, post taxes and transf...  TOT  Total population
# 4  Gini (disposable income, post taxes and transf...  TOT  Total population
#
#   DEFINITION          Definition   METHODO                       Methodology  \
# 0    CURRENT  Current definition  METH2012  New income definition since 2012
# 1    CURRENT  Current definition  METH2012  New income definition since 2012
# 2    CURRENT  Current definition  METH2012  New income definition since 2012
# 3    CURRENT  Current definition  METH2012  New income definition since 2012
# 4    CURRENT  Current definition  METH2011      Income definition until 2011
#
#    ...  Year  Unit Code       Unit PowerCode Code  PowerCode  \
# 0  ...  2012     0_TO_1  0-1 scale              0      Units
# 1  ...  2014     0_TO_1  0-1 scale              0      Units
# 2  ...  2016     0_TO_1  0-1 scale              0      Units
# 3  ...  2018     0_TO_1  0-1 scale              0      Units
# 4  ...  2004     0_TO_1  0-1 scale              0      Units
#
#   Reference Period Code  Reference Period  Value  Flag Codes Flags
# 0                   NaN               NaN  0.326         NaN   NaN
# 1                   NaN               NaN  0.337         NaN   NaN
# 2                   NaN               NaN  0.330         NaN   NaN
# 3                   NaN               NaN  0.325         NaN   NaN
# 4                   NaN               NaN  0.315         NaN   NaN
#
# [5 rows x 21 columns]

# %%
ocde_countries = df_ocde['LOCATION'].unique()
ocde_countries
# Out:
# array(['AUS', 'AUT', 'BEL', 'CAN', 'CZE', 'DNK', 'FIN', 'FRA', 'DEU',
#        'GRC', 'HUN', 'ISL', 'IRL', 'ITA', 'JPN', 'KOR', 'LUX', 'MEX',
#        'NLD', 'NZL', 'NOR', 'POL', 'PRT', 'SVK', 'ESP', 'SWE', 'CHE',
#        'TUR', 'GBR', 'USA', 'CHL', 'EST', 'ISR', 'RUS', 'SVN', 'LVA',
#        'LTU', 'BRA', 'CHN', 'CRI', 'IND', 'ZAF', 'BGR', 'ROU'],
#       dtype=object)

# %%
fig, ax = plt.subplots(1,1, figsize=(8,6))

for country in ocde_countries:
    df_country = df[(df['country_code'] == country) & (df['reporting_year'] >= 1990)]
    color = 'red' if country == 'CHL' else 'lightgray'
    df_country.plot(x='reporting_year', y='gini', color=color, ax=ax, legend=False)
    
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(8,6))

for country in ocde_countries:
    df_country = df[(df['country_code'] == country) & (df['reporting_year'] >= 1990)]
    color = 'red' if country == 'CHL' else 'lightgray'
    df_country.plot(x='reporting_gdp', y='gini', color=color, ax=ax, legend=False)
    
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(8,6)) 

xmin, xmax = 18, 86

for country in df_gini['Entity'].unique():
    df_country = df_gini[df_gini['Entity'] == country]
    df_2015 = df_country[df_country['Year'] == 2015]
    x = df_2015['Gini index of income in 1990 (inc. non-survey years)'].item()
    y = df_2015['Gini index of income in 2015 (inc. non-survey years)'].item()
    
    if country == 'Chile':
        color = 'steelblue'
        alpha = 1.0
    elif df_2015['Code'].item() in ocde_countries:
        color = 'orange'
        alpha = 0.5
    else:
        color = 'lightgray'
        alpha = 0.5
    
    ax.scatter(x, y, color=color, alpha=alpha)
    
    
ax.plot([xmin, xmax], [xmin, xmax], '--', color="#d2d2d2")
ax.set_xlim([xmin, xmax])
ax.set_ylim([22, 68])
plt.show()

# %% [markdown]
# ## Parte 4: Datos OCDE

# %%
df_ocde.head()
# Out:
#   LOCATION    Country MEASURE  \
# 0      AUS  Australia    GINI
# 1      AUS  Australia    GINI
# 2      AUS  Australia    GINI
# 3      AUS  Australia    GINI
# 4      AUS  Australia    GINI
#
#                                              Measure  AGE         Age group  \
# 0  Gini (disposable income, post taxes and transf...  TOT  Total population
# 1  Gini (disposable income, post taxes and transf...  TOT  Total population
# 2  Gini (disposable income, post taxes and transf...  TOT  Total population
# 3  Gini (disposable income, post taxes and transf...  TOT  Total population
# 4  Gini (disposable income, post taxes and transf...  TOT  Total population
#
#   DEFINITION          Definition   METHODO                       Methodology  \
# 0    CURRENT  Current definition  METH2012  New income definition since 2012
# 1    CURRENT  Current definition  METH2012  New income definition since 2012
# 2    CURRENT  Current definition  METH2012  New income definition since 2012
# 3    CURRENT  Current definition  METH2012  New income definition since 2012
# 4    CURRENT  Current definition  METH2011      Income definition until 2011
#
#    ...  Year  Unit Code       Unit PowerCode Code  PowerCode  \
# 0  ...  2012     0_TO_1  0-1 scale              0      Units
# 1  ...  2014     0_TO_1  0-1 scale              0      Units
# 2  ...  2016     0_TO_1  0-1 scale              0      Units
# 3  ...  2018     0_TO_1  0-1 scale              0      Units
# 4  ...  2004     0_TO_1  0-1 scale              0      Units
#
#   Reference Period Code  Reference Period  Value  Flag Codes Flags
# 0                   NaN               NaN  0.326         NaN   NaN
# 1                   NaN               NaN  0.337         NaN   NaN
# 2                   NaN               NaN  0.330         NaN   NaN
# 3                   NaN               NaN  0.325         NaN   NaN
# 4                   NaN               NaN  0.315         NaN   NaN
#
# [5 rows x 21 columns]

# %%
df_ocde['Measure'].unique()
# Out:
# array(['Gini (disposable income, post taxes and transfers)',
#        'Consumer Price Index (base 2010=100)',
#        'Age group 0-17: Poverty rate after taxes and transfers',
#        'Total earnings (current prices)',
#        'Income from self-employment (current prices)',
#        'Taxes and social security contributions paid directly by households (Current prices)',
#        'Age group 0-17: mean disposable income (current prices)',
#        'Age group 18-25: mean disposable income (current prices)',
#        'Capital income (current prices)',
#        'Age group 18-25: Poverty rate after taxes and transfers',
#        'Purchasing Power Parities for private consumption',
#        'Standard error Gini (post taxes and transfers)',
#        'Mean disposable income (current prices)',
#        'Gini (market income, before taxes and transfers)',
#        'Age group 26-40: Poverty rate after taxes and transfers',
#        'Income from self-employment and from goods produced for own consumption (current prices)',
#        'Capital and private transfers (current prices)',
#        'Current transfers paid by households to non-profit institutions and other households (Current prices)',
#        'Age group 26-40: mean disposable income (current prices)',
#        'Age group 41-50: mean disposable income (current prices)',
#        'Current transfers received (Current prices)',
#        'Age group 41-50: Poverty rate after taxes and transfers',
#        'Median disposable income (current prices)',
#        'Age group 51-65: Poverty rate after taxes and transfers',
#        'Current transfers paid (Current prices)',
#        'Age group 51-65: mean disposable income (current prices)',
#        'Age group 66-75: mean disposable income (current prices)',
#        'Age group 66-75: Poverty rate after taxes and transfers',
#        'Palma ratio',
#        'Age group 76+: Poverty rate after taxes and transfers',
#        'Age group 76+: mean disposable income (current prices)',
#        'All age groups: mean disposable income (current prices)',
#        'Poverty rate before taxes and transfers, Poverty line 50%',
#        'Poverty rate after taxes and transfers, Poverty line 50%',
#        'Mean Poverty gap after taxes and transfers, Poverty line 50%',
#        'Median Poverty gap after taxes and transfers, Poverty line 50%',
#        'All age groups: Poverty rate after taxes and transfers',
#        'Poverty rate before taxes and transfers, Poverty line 60%',
#        'Poverty rate after taxes and transfers, Poverty line 60%',
#        'Mean Poverty gap after taxes and transfers, Poverty line 60%',
#        'Median Poverty gap after taxes and transfers, Poverty line 60%',
#        'P90/P10 disposable income decile ratio',
#        'P90/P50  disposable income decile ratio',
#        'P50/P10  disposable income decile ratio',
#        'S80/S20 disposable income quintile share',
#        'Total number of individuals', 'Age group 0-17: share',
#        'Age group 18-25: share', 'Age group 26-40: share',
#        'Age group 41-50: share', 'Age group 51-65: share',
#        'Age group 66-75: share', 'Age group 76+: share',
#        'Total number of households',
#        'Income from own consumption (Current prices)',
#        'Contributions paid by households to employment-related social insurance schemes (Current prices)',
#        'All working-age household types: mean disposable income (current prices)',
#        'All  working-age household types: Poverty rate before taxes and transfers',
#        'All  working-age household types: Poverty rate after taxes and transfers',
#        'Consumer Price Index (base 2015=100)'], dtype=object)

# %%
fig, ax = plt.subplots(1,1, figsize=(8,6)) 

# for country in ocde_countries:
for country in ['CHL']:
    df_country = df_ocde[(df_ocde['LOCATION'] == country)
                         & (df_ocde['Year'] >= 1990)
                        & (df_ocde['Measure'] == 'Gini (disposable income, post taxes and transfers)')
    ]
    color = 'red' if country == 'CHL' else 'lightgray'
    df_country.plot(x='Year', y='Value', color=color, ax=ax, legend=False, alpha=0.5)
    
plt.show()

# %%
df_country
# Out:
#       LOCATION Country MEASURE  \
# 24357      CHL   Chile    GINI
# 24358      CHL   Chile    GINI
# 24359      CHL   Chile    GINI
# 40554      CHL   Chile    GINI
# 40555      CHL   Chile    GINI
# 40556      CHL   Chile    GINI
# 53739      CHL   Chile    GINI
# 53740      CHL   Chile    GINI
# 53741      CHL   Chile    GINI
# 57988      CHL   Chile    GINI
# 57989      CHL   Chile    GINI
# 57990      CHL   Chile    GINI
# 57991      CHL   Chile    GINI
# 57992      CHL   Chile    GINI
# 60213      CHL   Chile    GINI
# 60214      CHL   Chile    GINI
# 60215      CHL   Chile    GINI
# 60216      CHL   Chile    GINI
# 60217      CHL   Chile    GINI
# 61467      CHL   Chile    GINI
# 61468      CHL   Chile    GINI
# 61469      CHL   Chile    GINI
# 61470      CHL   Chile    GINI
# 61471      CHL   Chile    GINI
#
#                                                  Measure  AGE  \
# 24357  Gini (disposable income, post taxes and transf...  TOT
# 24358  Gini (disposable income, post taxes and transf...  TOT
# 24359  Gini (disposable income, post taxes and transf...  TOT
# 40554  Gini (disposable income, post taxes and transf...   WA
# 40555  Gini (disposable income, post taxes and transf...   WA
# 40556  Gini (disposable income, post taxes and transf...   WA
# 53739  Gini (disposable income, post taxes and transf...  OLD
# 53740  Gini (disposable income, post taxes and transf...  OLD
# 53741  Gini (disposable income, post taxes and transf...  OLD
# 57988  Gini (disposable income, post taxes and transf...  TOT
# 57989  Gini (disposable income, post taxes and transf...  TOT
# 57990  Gini (disposable income, post taxes and transf...  TOT
# 57991  Gini (disposable income, post taxes and transf...  TOT
# 57992  Gini (disposable income, post taxes and transf...  TOT
# 60213  Gini (disposable income, post taxes and transf...   WA
# 60214  Gini (disposable income, post taxes and transf...   WA
# 60215  Gini (disposable income, post taxes and transf...   WA
# 60216  Gini (disposable income, post taxes and transf...   WA
# 60217  Gini (disposable income, post taxes and transf...   WA
# 61467  Gini (disposable income, post taxes and transf...  OLD
# 61468  Gini (disposable income, post taxes and transf...  OLD
# 61469  Gini (disposable income, post taxes and transf...  OLD
# 61470  Gini (disposable income, post taxes and transf...  OLD
# 61471  Gini (disposable income, post taxes and transf...  OLD
#
#                                  Age group DEFINITION          Definition  \
# 24357                     Total population    CURRENT  Current definition
# 24358                     Total population    CURRENT  Current definition
# 24359                     Total population    CURRENT  Current definition
# 40554        Working age population: 18-65    CURRENT  Current definition
# 40555        Working age population: 18-65    CURRENT  Current definition
# 40556        Working age population: 18-65    CURRENT  Current definition
# 53739  Retirement age population: above 65    CURRENT  Current definition
# 53740  Retirement age population: above 65    CURRENT  Current definition
# 53741  Retirement age population: above 65    CURRENT  Current definition
# 57988                     Total population    CURRENT  Current definition
# 57989                     Total population    CURRENT  Current definition
# 57990                     Total population    CURRENT  Current definition
# 57991                     Total population    CURRENT  Current definition
# 57992                     Total population    CURRENT  Current definition
# 60213        Working age population: 18-65    CURRENT  Current definition
# 60214        Working age population: 18-65    CURRENT  Current definition
# 60215        Working age population: 18-65    CURRENT  Current definition
# 60216        Working age population: 18-65    CURRENT  Current definition
# 60217        Working age population: 18-65    CURRENT  Current definition
# 61467  Retirement age population: above 65    CURRENT  Current definition
# 61468  Retirement age population: above 65    CURRENT  Current definition
# 61469  Retirement age population: above 65    CURRENT  Current definition
# 61470  Retirement age population: above 65    CURRENT  Current definition
# 61471  Retirement age population: above 65    CURRENT  Current definition
#
#         METHODO                       Methodology  ...  Year  Unit Code  \
# 24357  METH2011      Income definition until 2011  ...  2006     0_TO_1
# 24358  METH2011      Income definition until 2011  ...  2009     0_TO_1
# 24359  METH2011      Income definition until 2011  ...  2011     0_TO_1
# 40554  METH2011      Income definition until 2011  ...  2006     0_TO_1
# 40555  METH2011      Income definition until 2011  ...  2009     0_TO_1
# 40556  METH2011      Income definition until 2011  ...  2011     0_TO_1
# 53739  METH2011      Income definition until 2011  ...  2006     0_TO_1
# 53740  METH2011      Income definition until 2011  ...  2009     0_TO_1
# 53741  METH2011      Income definition until 2011  ...  2011     0_TO_1
# 57988  METH2012  New income definition since 2012  ...  2009     0_TO_1
# 57989  METH2012  New income definition since 2012  ...  2011     0_TO_1
# 57990  METH2012  New income definition since 2012  ...  2013     0_TO_1
# 57991  METH2012  New income definition since 2012  ...  2015     0_TO_1
# 57992  METH2012  New income definition since 2012  ...  2017     0_TO_1
# 60213  METH2012  New income definition since 2012  ...  2009     0_TO_1
# 60214  METH2012  New income definition since 2012  ...  2011     0_TO_1
# 60215  METH2012  New income definition since 2012  ...  2013     0_TO_1
# 60216  METH2012  New income definition since 2012  ...  2015     0_TO_1
# 60217  METH2012  New income definition since 2012  ...  2017     0_TO_1
# 61467  METH2012  New income definition since 2012  ...  2009     0_TO_1
# 61468  METH2012  New income definition since 2012  ...  2011     0_TO_1
# 61469  METH2012  New income definition since 2012  ...  2013     0_TO_1
# 61470  METH2012  New income definition since 2012  ...  2015     0_TO_1
# 61471  METH2012  New income definition since 2012  ...  2017     0_TO_1
#
#             Unit PowerCode Code  PowerCode Reference Period Code  \
# 24357  0-1 scale              0      Units                   NaN
# 24358  0-1 scale              0      Units                   NaN
# 24359  0-1 scale              0      Units                   NaN
# 40554  0-1 scale              0      Units                   NaN
# 40555  0-1 scale              0      Units                   NaN
# 40556  0-1 scale              0      Units                   NaN
# 53739  0-1 scale              0      Units                   NaN
# 53740  0-1 scale              0      Units                   NaN
# 53741  0-1 scale              0      Units                   NaN
# 57988  0-1 scale              0      Units                   NaN
# 57989  0-1 scale              0      Units                   NaN
# 57990  0-1 scale              0      Units                   NaN
# 57991  0-1 scale              0      Units                   NaN
# 57992  0-1 scale              0      Units                   NaN
# 60213  0-1 scale              0      Units                   NaN
# 60214  0-1 scale              0      Units                   NaN
# 60215  0-1 scale              0      Units                   NaN
# 60216  0-1 scale              0      Units                   NaN
# 60217  0-1 scale              0      Units                   NaN
# 61467  0-1 scale              0      Units                   NaN
# 61468  0-1 scale              0      Units                   NaN
# 61469  0-1 scale              0      Units                   NaN
# 61470  0-1 scale              0      Units                   NaN
# 61471  0-1 scale              0      Units                   NaN
#
#        Reference Period  Value  Flag Codes Flags
# 24357               NaN  0.511         NaN   NaN
# 24358               NaN  0.510         NaN   NaN
# 24359               NaN  0.503         NaN   NaN
# 40554               NaN  0.507         NaN   NaN
# 40555               NaN  0.514         NaN   NaN
# 40556               NaN  0.502         NaN   NaN
# 53739               NaN  0.496         NaN   NaN
# 53740               NaN  0.482         NaN   NaN
# 53741               NaN  0.465         NaN   NaN
# 57988               NaN  0.480         NaN   NaN
# 57989               NaN  0.471         NaN   NaN
# 57990               NaN  0.465         NaN   NaN
# 57991               NaN  0.454         NaN   NaN
# 57992               NaN  0.460         NaN   NaN
# 60213               NaN  0.484         NaN   NaN
# 60214               NaN  0.471         NaN   NaN
# 60215               NaN  0.467         NaN   NaN
# 60216               NaN  0.453         NaN   NaN
# 60217               NaN  0.459         NaN   NaN
# 61467               NaN  0.442         NaN   NaN
# 61468               NaN  0.426         NaN   NaN
# 61469               NaN  0.428         NaN   NaN
# 61470               NaN  0.436         NaN   NaN
# 61471               NaN  0.441         NaN   NaN
#
# [24 rows x 21 columns]

# %%
fig, ax = plt.subplots(1,1, figsize=(8,6)) 

for country in ocde_countries:
# for country in ['CHL']:
    df_country = df_ocde[(df_ocde['LOCATION'] == country)
                         & (df_ocde['Year'] >= 1990)
                         & (df_ocde['Measure'] == 'Gini (disposable income, post taxes and transfers)')
                         & (df_ocde['AGE'] == 'TOT')
                         & (df_ocde['METHODO'] == 'METH2012')
    ]
    color = 'red' if country == 'CHL' else 'lightgray'
    df_country.plot(x='Year', y='Value', color=color, ax=ax, legend=False, alpha=0.5)
    
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(8,6)) 

for idx_country, country in enumerate(ocde_countries):
    
    df_after = df_ocde[(df_ocde['LOCATION'] == country)
                         & (df_ocde['Year'] >= 1990)
                         & (df_ocde['Measure'] == 'Gini (disposable income, post taxes and transfers)')
                         & (df_ocde['AGE'] == 'TOT')
                         & (df_ocde['METHODO'] == 'METH2012')]
    value_after = df_after.iloc[-1]['Value']
    
    df_before = df_ocde[(df_ocde['LOCATION'] == country)
                         & (df_ocde['Year'] >= 1990)
                         & (df_ocde['Measure'] == 'Gini (market income, before taxes and transfers)')
                         & (df_ocde['AGE'] == 'TOT')
                         & (df_ocde['METHODO'] == 'METH2012')]
    value_before = df_before.iloc[-1]['Value']
    
    color = 'red' if country == 'CHL' else 'lightgray'
    
    ax.hlines(idx_country, value_before, value_after, colors=[color], alpha=0.5)
    ax.scatter([value_before], [idx_country], color='steelblue')
    ax.scatter([value_after], [idx_country], color='orange')

# %%
before = []
after = []

df_gap = pd.DataFrame()

for idx_country, country in enumerate(ocde_countries):
        
    df_after = df_ocde[(df_ocde['LOCATION'] == country)
                         & (df_ocde['Year'] >= 1990)
                         & (df_ocde['Measure'] == 'Gini (disposable income, post taxes and transfers)')
                         & (df_ocde['AGE'] == 'TOT')
                         & (df_ocde['METHODO'] == 'METH2012')]
    after.append(df_after.iloc[-1]['Value'])
    
    df_before = df_ocde[(df_ocde['LOCATION'] == country)
                         & (df_ocde['Year'] >= 1990)
                         & (df_ocde['Measure'] == 'Gini (market income, before taxes and transfers)')
                         & (df_ocde['AGE'] == 'TOT')
                         & (df_ocde['METHODO'] == 'METH2012')]
    before.append(df_before.iloc[-1]['Value'])
    
df_gap['country'] = ocde_countries
df_gap['before'] = before
df_gap['after'] = after
df_gap['gap'] = df_gap['before'] - df_gap['after']

df_gap.head()
# Out:
#   country  before  after    gap
# 0     AUS   0.454  0.325  0.129
# 1     AUT   0.486  0.274  0.212
# 2     BEL   0.489  0.262  0.227
# 3     CAN   0.421  0.301  0.120
# 4     CZE   0.432  0.248  0.184

# %%
by_after = df_gap.sort_values('after').reset_index()
by_gap = df_gap.sort_values('gap', ascending=False).reset_index()

# %%
by_after
# Out:
#     index country  before  after    gap
# 0      23     SVK   0.383  0.222  0.161
# 1      34     SVN   0.444  0.246  0.198
# 2       4     CZE   0.432  0.248  0.184
# 3      11     ISL   0.369  0.250  0.119
# 4      20     NOR   0.427  0.261  0.166
# 5       2     BEL   0.489  0.262  0.227
# 6       5     DNK   0.443  0.263  0.180
# 7       6     FIN   0.509  0.269  0.240
# 8       1     AUT   0.486  0.274  0.212
# 9      25     SWE   0.433  0.278  0.155
# 10     21     POL   0.452  0.281  0.171
# 11     10     HUN   0.463  0.286  0.177
# 12      8     DEU   0.494  0.289  0.205
# 13     12     IRL   0.520  0.292  0.228
# 14      7     FRA   0.519  0.292  0.227
# 15     18     NLD   0.444  0.296  0.148
# 16      3     CAN   0.421  0.301  0.120
# 17     31     EST   0.465  0.305  0.160
# 18     16     LUX   0.490  0.305  0.185
# 19      9     GRC   0.525  0.308  0.217
# 20     22     PRT   0.511  0.310  0.201
# 21     26     CHE   0.402  0.316  0.086
# 22     33     RUS   0.434  0.317  0.117
# 23     19     NZL   0.454  0.320  0.134
# 24     24     ESP   0.491  0.320  0.171
# 25      0     AUS   0.454  0.325  0.129
# 26     13     ITA   0.511  0.330  0.181
# 27     15     KOR   0.405  0.331  0.074
# 28     14     JPN   0.501  0.334  0.167
# 29     43     ROU   0.512  0.339  0.173
# 30     32     ISR   0.449  0.342  0.107
# 31     35     LVA   0.483  0.355  0.128
# 32     36     LTU   0.495  0.357  0.138
# 33     28     GBR   0.508  0.366  0.142
# 34     29     USA   0.505  0.395  0.110
# 35     27     TUR   0.492  0.397  0.095
# 36     42     BGR   0.523  0.402  0.121
# 37     17     MEX   0.435  0.420  0.015
# 38     30     CHL   0.495  0.460  0.035
# 39     37     BRA   0.582  0.481  0.101
# 40     39     CRI   0.551  0.487  0.064
# 41     40     IND   0.508  0.495  0.013
# 42     38     CHN   0.548  0.514  0.034
# 43     41     ZAF   0.709  0.618  0.091

# %%
by_gap
# Out:
#     index country  before  after    gap
# 0       6     FIN   0.509  0.269  0.240
# 1      12     IRL   0.520  0.292  0.228
# 2       7     FRA   0.519  0.292  0.227
# 3       2     BEL   0.489  0.262  0.227
# 4       9     GRC   0.525  0.308  0.217
# 5       1     AUT   0.486  0.274  0.212
# 6       8     DEU   0.494  0.289  0.205
# 7      22     PRT   0.511  0.310  0.201
# 8      34     SVN   0.444  0.246  0.198
# 9      16     LUX   0.490  0.305  0.185
# 10      4     CZE   0.432  0.248  0.184
# 11     13     ITA   0.511  0.330  0.181
# 12      5     DNK   0.443  0.263  0.180
# 13     10     HUN   0.463  0.286  0.177
# 14     43     ROU   0.512  0.339  0.173
# 15     24     ESP   0.491  0.320  0.171
# 16     21     POL   0.452  0.281  0.171
# 17     14     JPN   0.501  0.334  0.167
# 18     20     NOR   0.427  0.261  0.166
# 19     23     SVK   0.383  0.222  0.161
# 20     31     EST   0.465  0.305  0.160
# 21     25     SWE   0.433  0.278  0.155
# 22     18     NLD   0.444  0.296  0.148
# 23     28     GBR   0.508  0.366  0.142
# 24     36     LTU   0.495  0.357  0.138
# 25     19     NZL   0.454  0.320  0.134
# 26      0     AUS   0.454  0.325  0.129
# 27     35     LVA   0.483  0.355  0.128
# 28     42     BGR   0.523  0.402  0.121
# 29      3     CAN   0.421  0.301  0.120
# 30     11     ISL   0.369  0.250  0.119
# 31     33     RUS   0.434  0.317  0.117
# 32     29     USA   0.505  0.395  0.110
# 33     32     ISR   0.449  0.342  0.107
# 34     37     BRA   0.582  0.481  0.101
# 35     27     TUR   0.492  0.397  0.095
# 36     41     ZAF   0.709  0.618  0.091
# 37     26     CHE   0.402  0.316  0.086
# 38     15     KOR   0.405  0.331  0.074
# 39     39     CRI   0.551  0.487  0.064
# 40     30     CHL   0.495  0.460  0.035
# 41     38     CHN   0.548  0.514  0.034
# 42     17     MEX   0.435  0.420  0.015
# 43     40     IND   0.508  0.495  0.013

# %%
def plot_gini(df, ax):
    
    for idx_row, row in df.iterrows():
        
        color = 'red' if row['country'] == 'CHL' else 'lightgray'
        value_before = row['before']
        value_after = row['after']
    
        ax.hlines(idx_row, value_before, value_after, colors=[color], alpha=0.5)
        ax.scatter([value_before], [idx_row], color='steelblue')
        ax.scatter([value_after], [idx_row], color='orange')

fig, ax = plt.subplots(1,2,figsize=(12,6))
plot_gini(by_after, ax[0])
plot_gini(by_gap, ax[1])

plt.show()

# %% [markdown]
# ## Parte 5: Distribución de ingresos

# %%
fig, ax = plt.subplots(1,1, figsize=(8,6)) 

for country in ocde_countries:
# for country in ['CHL']:
    df_country = df_ocde[(df_ocde['LOCATION'] == country)
                         & (df_ocde['Year'] >= 1990)
                         & (df_ocde['Measure'] == 'P90/P10 disposable income decile ratio')
                         & (df_ocde['AGE'] == 'TOT')
                         & (df_ocde['METHODO'] == 'METH2012')
    ]
    color = 'red' if country == 'CHL' else 'lightgray'
    df_country.plot(x='Year', y='Value', color=color, ax=ax, legend=False, alpha=0.5)
    
plt.show()

# %%
df_chile
# Out:
#                    region_name region_code country_name country_code  \
# 322  Latin America & Caribbean         LAC        Chile          CHL
# 323  Latin America & Caribbean         LAC        Chile          CHL
# 324  Latin America & Caribbean         LAC        Chile          CHL
# 325  Latin America & Caribbean         LAC        Chile          CHL
# 326  Latin America & Caribbean         LAC        Chile          CHL
# 327  Latin America & Caribbean         LAC        Chile          CHL
# 328  Latin America & Caribbean         LAC        Chile          CHL
# 329  Latin America & Caribbean         LAC        Chile          CHL
# 330  Latin America & Caribbean         LAC        Chile          CHL
# 331  Latin America & Caribbean         LAC        Chile          CHL
# 332  Latin America & Caribbean         LAC        Chile          CHL
# 333  Latin America & Caribbean         LAC        Chile          CHL
# 334  Latin America & Caribbean         LAC        Chile          CHL
# 335  Latin America & Caribbean         LAC        Chile          CHL
# 336  Latin America & Caribbean         LAC        Chile          CHL
#
#      reporting_year reporting_level survey_acronym survey_coverage  \
# 322            1987        national          CASEN        national
# 323            1990        national          CASEN        national
# 324            1992        national          CASEN        national
# 325            1994        national          CASEN        national
# 326            1996        national          CASEN        national
# 327            1998        national          CASEN        national
# 328            2000        national          CASEN        national
# 329            2003        national          CASEN        national
# 330            2006        national          CASEN        national
# 331            2009        national          CASEN        national
# 332            2011        national          CASEN        national
# 333            2013        national          CASEN        national
# 334            2015        national          CASEN        national
# 335            2017        national          CASEN        national
# 336            2020        national          CASEN        national
#
#      survey_year welfare_type  ...   decile9  decile10       cpi         ppp  \
# 322       1987.0       income  ...  0.160075  0.453914  0.141201  478.995697
# 323       1990.0       income  ...  0.154096  0.470505  0.265681  478.995697
# 324       1992.0       income  ...  0.149427  0.451959  0.356878  478.995697
# 325       1994.0       income  ...  0.155901  0.459067  0.435449  478.995697
# 326       1996.0       income  ...  0.156687  0.444274  0.501988  478.995697
# 327       1998.0       income  ...  0.157075  0.449718  0.556358  478.995697
# 328       2000.0       income  ...  0.154262  0.425819  0.597324  478.995697
# 329       2003.0       income  ...  0.154101  0.413543  0.639934  478.995697
# 330       2006.0       income  ...  0.155561  0.378933  0.694008  478.995697
# 331       2009.0       income  ...  0.151857  0.382195  0.784435  478.995697
# 332       2011.0       income  ...  0.153459  0.372931  0.835362  478.995697
# 333       2013.0       income  ...  0.152660  0.373735  0.873375  478.995697
# 334       2015.0       income  ...  0.151542  0.360586  0.959573  478.995697
# 335       2017.0       income  ...  0.149540  0.363419  1.006627  478.995697
# 336       2020.0       income  ...  0.158416  0.357974  1.092927  478.995697
#
#      reporting_pop  reporting_gdp  reporting_pce  is_interpolated  \
# 322       12642917    4710.709892    2400.793312            False
# 323       13274617    5470.479736    2754.646852            False
# 324       13719818    6343.227129    3301.817823            False
# 325       14166346    6877.434435    3716.155714            False
# 326       14587367    7770.539111    4336.964275            False
# 327       14977736    8481.752131    4766.270043            False
# 328       15342350    8685.321794    4797.305129            False
# 329       15849649    9321.218536    5059.241111            False
# 330       16354507   10887.863776    6144.546774            False
# 331       16886184   11273.617502    6579.528584            False
# 332       17233584   12406.413571    7721.731971            False
# 333       17571511   13333.346834    8398.985217            False
# 334       17969356   13574.169238    8611.446615            False
# 335       18470435   13590.991346    8897.950706            False
# 336       19116209   12954.405354    8340.163281            False
#
#      distribution_type  estimation_type
# 322              micro           survey
# 323              micro           survey
# 324              micro           survey
# 325              micro           survey
# 326              micro           survey
# 327              micro           survey
# 328              micro           survey
# 329              micro           survey
# 330              micro           survey
# 331              micro           survey
# 332              micro           survey
# 333              micro           survey
# 334              micro           survey
# 335              micro           survey
# 336              micro           survey
#
# [15 rows x 40 columns]

# %%
years = []
decile_distribution = {}

deciles = [x for x in df_chile.columns if 'decile' in x]

for decile in deciles:
    decile_distribution[decile] = []

# %%
deciles
# Out:
# ['decile1',
#  'decile2',
#  'decile3',
#  'decile4',
#  'decile5',
#  'decile6',
#  'decile7',
#  'decile8',
#  'decile9',
#  'decile10']

# %%
decile_distribution
# Out:
# {'decile1': [],
#  'decile2': [],
#  'decile3': [],
#  'decile4': [],
#  'decile5': [],
#  'decile6': [],
#  'decile7': [],
#  'decile8': [],
#  'decile9': [],
#  'decile10': []}

# %%
for idx, row in df_chile.iterrows():
    years.append(row['reporting_year'])
    for decile in deciles:
        decile_distribution[decile].append(row[decile])
        
decile_distribution
# Out:
# {'decile1': [0.0116019492355596,
#   0.0118553955273044,
#   0.0143104217527041,
#   0.0122909713183081,
#   0.0133235354985257,
#   0.0125389539604489,
#   0.013084670194383,
#   0.0138081354912954,
#   0.0185468893648728,
#   0.019279423863461,
#   0.0205096688050581,
#   0.0214351527227739,
#   0.0223997074876653,
#   0.0226161399622648,
#   0.020621702524623],
#  'decile2': [0.0218358060539591,
#   0.021696968760948,
#   0.0241730402998276,
#   0.0223053614724533,
#   0.0231710301933902,
#   0.0225651331076592,
#   0.0252069888982955,
#   0.0262896764215879,
#   0.0310919011184767,
#   0.0323946965708239,
#   0.0329379434330706,
#   0.0337441146929893,
#   0.0350143089439125,
#   0.0350338370540364,
#   0.0341261530692532],
#  'decile3': [0.0294248948050559,
#   0.0289412320735623,
#   0.0319152438977235,
#   0.0297331369176112,
#   0.0311599028026939,
#   0.0304616985626497,
#   0.0339971852667012,
#   0.0351048674447191,
#   0.0401613315077447,
#   0.0410012838477892,
#   0.0418370544537457,
#   0.0421283871355779,
#   0.0439962762359756,
#   0.0440363767266668,
#   0.0431301088897192],
#  'decile4': [0.0376034393132926,
#   0.0367476297433231,
#   0.0397593240488367,
#   0.03755984339211,
#   0.0393679984694875,
#   0.0389069340072079,
#   0.0427383748056512,
#   0.0443867580750396,
#   0.049118228175563,
#   0.0497468496748836,
#   0.05090878590674,
#   0.0508106269532102,
#   0.0527407713941331,
#   0.0527384087985305,
#   0.0519533319047078],
#  'decile5': [0.0470670832578049,
#   0.0457218325086556,
#   0.0489121254012566,
#   0.0469859758212527,
#   0.0488056787199036,
#   0.0482889301164363,
#   0.05277258018708,
#   0.0548695742602043,
#   0.0592912309123516,
#   0.0594621036910394,
#   0.0602586814000542,
#   0.0603890925565171,
#   0.0621021549556723,
#   0.0622955722194321,
#   0.0614081120296403],
#  'decile6': [0.0591246804523411,
#   0.0574520263931939,
#   0.0608809426142373,
#   0.0588858296931906,
#   0.0609391024810913,
#   0.0602476583507698,
#   0.0651950393165597,
#   0.0672988324497242,
#   0.0711273043225895,
#   0.0708375008972582,
#   0.071316153838117,
#   0.0714905790101382,
#   0.0734339360145892,
#   0.0734727805527086,
#   0.0731361720554902],
#  'decile7': [0.0761779844810059,
#   0.0737932666475414,
#   0.0772169816215154,
#   0.0752820961827896,
#   0.0778187526585076,
#   0.0768131426496824,
#   0.0809602587996505,
#   0.0832968496336638,
#   0.0864063063911847,
#   0.085488421210527,
#   0.0866508084538248,
#   0.0858111078145008,
#   0.0881478924972677,
#   0.0878599780025887,
#   0.0879017370387365],
#  'decile8': [0.1031754857484735,
#   0.0991904398961526,
#   0.1014462742635413,
#   0.1019883548520254,
#   0.1044526042406575,
#   0.1033848795109306,
#   0.1059643622204776,
#   0.1073014821899936,
#   0.1097620011086948,
#   0.107737850279561,
#   0.1091910149452813,
#   0.107795209377079,
#   0.1100374746377436,
#   0.1089880181210324,
#   0.1113317789415875],
#  'decile9': [0.1600749868907423,
#   0.1540960904795343,
#   0.149426998458542,
#   0.155901330399394,
#   0.1566874128942395,
#   0.1570745628226109,
#   0.1542616247048011,
#   0.154101205416714,
#   0.1555614083290216,
#   0.1518569916685877,
#   0.15345921768041,
#   0.1526604842330117,
#   0.1515417680581548,
#   0.1495398535147739,
#   0.1584164350213],
#  'decile10': [0.4539136897617596,
#   0.4705051179697842,
#   0.4519586476418106,
#   0.4590670999508522,
#   0.4442739820414971,
#   0.4497181069115916,
#   0.4258189156064063,
#   0.4135426186170574,
#   0.3789333987695106,
#   0.3821948782960448,
#   0.3729306710836895,
#   0.3737352455042145,
#   0.3605857097748791,
#   0.3634190350479563,
#   0.35797446852493]}

# %%
fig, ax = plt.subplots()
ax.stackplot(years, decile_distribution.values(),
            labels = decile_distribution.keys(),
            alpha=0.8)

# ax.legend(loc='upper left')

ax.set_xlim([1987, 2020])
ax.set_ylim([0, 1])
plt.show()

# %% [markdown]
# ## Parte 6: Otros puntos de vista

# %% [markdown]
# [estos](https://twitter.com/cristobalotero/status/1192150305871253505) [dos](https://twitter.com/_Ignacio_Flores/status/1573179884020662275) hilos de Twitter

# %% [markdown]
# [World Inequality Database](https://wid.world)
