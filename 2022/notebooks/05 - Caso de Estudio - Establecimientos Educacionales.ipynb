# %% [markdown]
# # Clase 05 - Caso de Estudio: Establecimientos Educacionales

# %% [markdown]
# Profesor: **Fernando Becerra**, f.becerra@udd.cl, [www.fernandobecerra.com](www.fernandobecerra.com)

# %% [markdown]
# En esta clase analizaremos un caso de estudio de comienzo a fin, en el cual la idea es explorar los dats a través de la visualización de información para poder delinear una narrativa. En particular, analizaremos datos de los establedicmientos educacionales de la Región Metropolitana, aunque la aplicación del análisis no tiene porqué esta acotado a esa área.
#
# Este ejercicio fue inspirado por una visualización que vi en [Twitter](https://twitter.com/jcovarrubia/status/1539440850257727489). Recuerden que siempre es bueno seguir gente que trabaje en datos y estar atento a lo que ell@s están haciendo. En nuestro caso no haremos exactamente el mismo proceso, sino que lo complementaremos con otras bases de datos para hacer un análisis más completo.

# %% [markdown]
# Lo primero es lo primero: importar lo típico

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Como dice el tuit, los datos son sacados del [portal de datos abiertos del Ministerio de Educación](https://datosabiertos.mineduc.cl).  Si nos vamos a "Estudiantes y Párvulos" y después ["Matrícula por estudiante"](https://datosabiertos.mineduc.cl/matricula-por-estudiante-2/), podemos acceder al archivo en formato `zip`. Este archivo incluye documentos de texto que nos ayudan con los nombres de las columnas y los valores que cada una puede tomar.
#
# A nosotr@s nos interesa cargar el archivos `csv` que viene dentro y empezar a ver qué información tiene.

# %%
df = pd.read_csv('../data/educacion/Matricula-por-estudiante-2021/20210913_Matrícula_unica_2021_20210430_WEB.CSV', sep=';')
df.head()
# Out:
# <ipython-input-2-a093e8330839>:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/educacion/Matricula-por-estudiante-2021/20210913_Matrícula_unica_2021_20210430_WEB.CSV', sep=';')
#    AGNO  RBD  DGV_RBD                  NOM_RBD  COD_REG_RBD NOM_REG_RBD_A  \
# 0  2021    1        9  LICEO POLITECNICO ARICA           15           AYP
# 1  2021    1        9  LICEO POLITECNICO ARICA           15           AYP
# 2  2021    1        9  LICEO POLITECNICO ARICA           15           AYP
# 3  2021    1        9  LICEO POLITECNICO ARICA           15           AYP
# 4  2021    1        9  LICEO POLITECNICO ARICA           15           AYP
#
#    COD_PRO_RBD  COD_COM_RBD NOM_COM_RBD  COD_DEPROV_RBD  ... FEC_NAC_ALU  \
# 0          151        15101       ARICA             151  ...      196703
# 1          151        15101       ARICA             151  ...      199607
# 2          151        15101       ARICA             151  ...      196911
# 3          151        15101       ARICA             151  ...      197802
# 4          151        15101       ARICA             151  ...      199509
#
#    EDAD_ALU  COD_REG_ALU  COD_COM_ALU  NOM_COM_ALU  COD_SEC  COD_ESPE  \
# 0        54           15        15101        ARICA      410     41001
# 1        24           15        15101        ARICA      410     41001
# 2        51           15        15101        ARICA      410     41001
# 3        43            1         1101      IQUIQUE      410     41001
# 4        25           15        15101        ARICA      410     41001
#
#    COD_RAMA  COD_MEN  ENS
# 0       400        0   13
# 1       400        0   13
# 2       400        0   13
# 3       400        0   13
# 4       400        0   13
#
# [5 rows x 36 columns]

# %% [markdown]
# Lo primero que haremos para hacer el análisis un poco más fácil, es restringir el análisis a la Región Metropolitana. Para eso, eligiremos sólo los establecimientos y alumn@s que se ubican en dicha región, y filtraremos los datos en base a eso.

# %%
df_rm = df[(df['COD_REG_RBD'] == 13) & (df['COD_REG_ALU'] == 13)].reset_index()
df_rm.head()
# Out:
#      index  AGNO   RBD  DGV_RBD                   NOM_RBD  COD_REG_RBD  \
# 0  1324745  2021  8485        9  LICEO INSTITUTO NACIONAL           13
# 1  1324746  2021  8485        9  LICEO INSTITUTO NACIONAL           13
# 2  1324747  2021  8485        9  LICEO INSTITUTO NACIONAL           13
# 3  1324748  2021  8485        9  LICEO INSTITUTO NACIONAL           13
# 4  1324749  2021  8485        9  LICEO INSTITUTO NACIONAL           13
#
#   NOM_REG_RBD_A  COD_PRO_RBD  COD_COM_RBD NOM_COM_RBD  ...  FEC_NAC_ALU  \
# 0            RM          131        13101    SANTIAGO  ...       200811
# 1            RM          131        13101    SANTIAGO  ...       200812
# 2            RM          131        13101    SANTIAGO  ...       200902
# 3            RM          131        13101    SANTIAGO  ...       200807
# 4            RM          131        13101    SANTIAGO  ...       200801
#
#   EDAD_ALU  COD_REG_ALU  COD_COM_ALU  NOM_COM_ALU  COD_SEC  COD_ESPE  \
# 0       12           13        13101     SANTIAGO        0         0
# 1       12           13        13104     CONCHALÍ        0         0
# 2       12           13        13101     SANTIAGO        0         0
# 3       12           13        13102    CERRILLOS        0         0
# 4       13           13        13120        ÑUÑOA        0         0
#
#    COD_RAMA  COD_MEN  ENS
# 0         0        0    3
# 1         0        0    3
# 2         0        0    3
# 3         0        0    3
# 4         0        0    3
#
# [5 rows x 37 columns]

# %% [markdown]
# Para empezar a familiarizarnos con los datos y con ayuda de los documentos adjuntos, empezamos a ver de qué se trata cada columna y como vamos a trabajar con ellas. Por ejemplo, sería bueno saber el número total de establecimientos luego de haberlos filtrados.

# %%
len(pd.unique(df_rm['RBD']))
# Out:
# 2918

# %% [markdown]
# ## Parte 1: Movimiento general de la matrícula en la Región Metropolitana

# %% [markdown]
# Para comenzar el análisis, nos inspiraremos en un ejemplo visto en las clases anteriores: la encuesta origen-destino. Veremos la movilidad de cada estudiante en base a la comuna donde vive y la comuna donde estudia. Para eso reutilizaremos código de ese ejemplo para calcularel flujo desde una comuna a otra,

# %%
from sklearn.preprocessing import normalize

def normalize_rows(df):
    df = pd.DataFrame(normalize(df, norm='l1'), index=df.index, columns=df.columns)
    return df

def normalize_columns(df):
    df = pd.DataFrame(normalize(df, norm='l1', axis=0), index=df.index, columns=df.columns)
    return df

# %%
flujos = (
    df_rm.groupby(['NOM_COM_RBD', 'NOM_COM_ALU'])
        .agg(n_matriculas=('NOM_COM_ALU', 'count'))
        ['n_matriculas'].unstack(fill_value=0)
        .pipe(normalize_rows)
)
flujos.head()
# Out:
# NOM_COM_ALU         ALHUÉ      BUIN  CALERA DE TANGO  CERRILLOS  CERRO NAVIA  \
# NOM_COM_RBD
# ALHUÉ            0.950326  0.000814         0.000000   0.000000     0.000000
# BUIN             0.000546  0.823562         0.002595   0.000819     0.001912
# CALERA DE TANGO  0.000000  0.012522         0.616452   0.007128     0.000771
# CERRILLOS        0.000079  0.000475         0.000871   0.632816     0.002533
# CERRO NAVIA      0.000000  0.000356         0.000119   0.002436     0.751307
#
# NOM_COM_ALU        COLINA  CONCHALÍ  CURACAVÍ  EL BOSQUE  EL MONTE  ...  \
# NOM_COM_RBD                                                         ...
# ALHUÉ            0.000000  0.000000  0.000000   0.000000  0.000000  ...
# BUIN             0.000501  0.000910  0.000228   0.004324  0.000637  ...
# CALERA DE TANGO  0.001926  0.000771  0.000385   0.006165  0.000963  ...
# CERRILLOS        0.000792  0.001029  0.000158   0.003404  0.000871  ...
# CERRO NAVIA      0.001485  0.001366  0.000594   0.001961  0.000416  ...
#
# NOM_COM_ALU      SAN JOAQUÍN  SAN JOSÉ DE MAIPO  SAN MIGUEL  SAN PEDRO  \
# NOM_COM_RBD
# ALHUÉ               0.000000           0.000000    0.000000   0.000814
# BUIN                0.001639           0.000000    0.003551   0.000000
# CALERA DE TANGO     0.001156           0.000385    0.004431   0.000000
# CERRILLOS           0.002137           0.000000    0.002533   0.000079
# CERRO NAVIA         0.001069           0.000000    0.000535   0.000000
#
# NOM_COM_ALU      SAN RAMÓN  SANTIAGO  TALAGANTE    TILTIL  VITACURA     ÑUÑOA
# NOM_COM_RBD
# ALHUÉ             0.000000  0.023616   0.000000  0.000000  0.000000  0.000000
# BUIN              0.001229  0.021258   0.001866  0.000182  0.000819  0.002413
# CALERA DE TANGO   0.001926  0.025043   0.030052  0.000000  0.000963  0.003082
# CERRILLOS         0.001504  0.058335   0.000950  0.000079  0.000079  0.001187
# CERRO NAVIA       0.000535  0.045449   0.000059  0.000119  0.000059  0.000535
#
# [5 rows x 52 columns]

# %% [markdown]
# Una de mis visualizaciones favoritas es el heat map, por lo que ocuparemos ese gráfico para visualizar esta red.

# %%
fig, ax = plt.subplots(1,1, figsize=(14,14))

sns.heatmap(flujos, cmap='magma_r', square=True, linewidths=1,
           cbar_kws={'shrink': 0.8, 'label': 'Fracción de matrículas'})
plt.xlabel('Comuna Establecimiento')
plt.ylabel('Comuna Estudiantes')

plt.show()

# %% [markdown]
# ## Parte 2: Origen de la matrícula de cada establecimiento

# %% [markdown]
# La visualización anterior nos da una idea general de como se mueven los estudiantes desde una comuna a otra, pero ahora queremos ir más al detalle. Comenzar con una vista general para luego ir a lo específico es una buena forma de hacer la información más digerible.
#
# En este paso calcularemos la cantidad de matrículas de cada colegio por comuna de origen.

# %%
establecimientos = (
    df_rm.groupby(['RBD', 'NOM_RBD', 'COD_COM_ALU'])
        .agg(n_matriculas=('COD_COM_ALU', 'count'))
)
establecimientos.head()
# Out:
#                                            n_matriculas
# RBD  NOM_RBD                  COD_COM_ALU
# 8485 LICEO INSTITUTO NACIONAL 13101                 369
#                               13102                  34
#                               13103                 130
#                               13104                 151
#                               13105                  66

# %% [markdown]
# Para hacerlo comparables entre distintos establecimientos educacionales, lo transformaremos a porcentaje de matrícula.

# %%
establecimientos['n_percent'] = establecimientos['n_matriculas'] / establecimientos.groupby('RBD')['n_matriculas'].transform('sum')
establecimientos.head()
# Out:
#                                            n_matriculas  n_percent
# RBD  NOM_RBD                  COD_COM_ALU
# 8485 LICEO INSTITUTO NACIONAL 13101                 369   0.102159
#                               13102                  34   0.009413
#                               13103                 130   0.035991
#                               13104                 151   0.041805
#                               13105                  66   0.018272

# %%
establecimientos = establecimientos.reset_index()
establecimientos.head()
# Out:
#     RBD                   NOM_RBD  COD_COM_ALU  n_matriculas  n_percent
# 0  8485  LICEO INSTITUTO NACIONAL        13101           369   0.102159
# 1  8485  LICEO INSTITUTO NACIONAL        13102            34   0.009413
# 2  8485  LICEO INSTITUTO NACIONAL        13103           130   0.035991
# 3  8485  LICEO INSTITUTO NACIONAL        13104           151   0.041805
# 4  8485  LICEO INSTITUTO NACIONAL        13105            66   0.018272

# %% [markdown]
# ¡Ahora es momento de empezar a mapear! Para eso importamos `geopandas`

# %%
import geopandas as gpd

# %% [markdown]
# Y cargamos los arhivos `shp` sacados desde la [Biblioteca del Congreso Nacional](https://www.bcn.cl/siit/mapas_vectoriales/index_html).

# %%
comunas = gpd.read_file('../data/bcn/Comunas/comunas.shp')
comunas.head()
# Out:
#    objectid     shape_leng  dis_elec  cir_sena  cod_comuna  codregion  \
# 0        48  170038.624165        16         8        6204          6
# 1        29  125730.104795        15         8        6102          6
# 2        30   63026.084422        15         8        6103          6
# 3        31   89840.903562        15         8        6104          6
# 4        78  122626.493264        23        11        9121          9
#
#      st_area_sh     st_length_                                    Region  \
# 0  9.685774e+08  206184.271675  Región del Libertador Bernardo O'Higgins
# 1  4.157446e+08  151911.576827  Región del Libertador Bernardo O'Higgins
# 2  1.448565e+08   76355.326122  Región del Libertador Bernardo O'Higgins
# 3  3.256572e+08  108874.623150  Región del Libertador Bernardo O'Higgins
# 4  6.990727e+08  156680.410681                    Región de La Araucanía
#
#       Comuna      Provincia                                           geometry
# 0  Marchigüe  Cardenal Caro  POLYGON ((-7992818.789 -4056669.319, -7992731....
# 1    Codegua      Cachapoal  POLYGON ((-7831651.813 -4022443.109, -7831596....
# 2     Coinco      Cachapoal  POLYGON ((-7892616.357 -4060673.364, -7892621....
# 3   Coltauco      Cachapoal  POLYGON ((-7906457.717 -4051723.734, -7906266....
# 4   Cholchol         Cautín  POLYGON ((-8121756.186 -4645860.295, -8121644....

# %% [markdown]
# Exploramos las regiones disponible para poder filtrarlas

# %%
pd.unique(comunas['Region'])
# Out:
# array(["Región del Libertador Bernardo O'Higgins",
#        'Región de La Araucanía', 'Región Metropolitana de Santiago',
#        'Región de Los Lagos', 'Región de Los Ríos', 'Región del Maule',
#        'Región de Coquimbo', 'Región de Magallanes y Antártica Chilena',
#        'Zona sin demarcar', 'Región de Valparaíso', 'Región del Bío-Bío',
#        'Región de Aysén del Gral.Ibañez del Campo', 'Región de Tarapacá',
#        'Región de Arica y Parinacota', 'Región de Antofagasta',
#        'Región de Ñuble', 'Región de Atacama'], dtype=object)

# %% [markdown]
# Y ahora filtramos los datos

# %%
comunas_rm = comunas[comunas['Region'] == 'Región Metropolitana de Santiago'].reset_index()
comunas_rm.head()
# Out:
#    index  objectid    shape_leng  dis_elec  cir_sena  cod_comuna  codregion  \
# 0     26       330  13987.326781        10         7       13129         13
# 1     36       331  13311.641304        13         7       13130         13
# 2     47       332  11733.486710        13         7       13131         13
# 3     57       309  11488.695747         9         7       13108         13
# 4     61       310  12797.595762        13         7       13109         13
#
#      st_area_sh    st_length_                            Region  \
# 0  1.424341e+07  16812.167615  Región Metropolitana de Santiago
# 1  1.389538e+07  15988.816037  Región Metropolitana de Santiago
# 2  9.056280e+06  14061.528858  Región Metropolitana de Santiago
# 3  1.068637e+07  14088.417488  Región Metropolitana de Santiago
# 4  1.454185e+07  15442.412755  Región Metropolitana de Santiago
#
#           Comuna Provincia                                           geometry
# 0    San Joaquín  Santiago  POLYGON ((-7861762.687 -3958307.095, -7861708....
# 1     San Miguel  Santiago  POLYGON ((-7863229.775 -3964360.652, -7863319....
# 2      San Ramón  Santiago  POLYGON ((-7863398.118 -3964354.273, -7863319....
# 3  Independencia  Santiago  POLYGON ((-7865631.125 -3948404.075, -7865643....
# 4    La Cisterna  Santiago  POLYGON ((-7865040.615 -3968217.521, -7865077....

# %% [markdown]
# Para ver que todo esté en orden, lo vamos a graficar primero.

# %%
fig, ax = plt.subplots(1,1,figsize=(12,8))

comunas_rm.plot(ax=ax)

plt.show()

# %% [markdown]
# Ahora definiremos una función que reciba el nombre de un establecimiento y grafique el porcentaje de estudiantes matriculados por comuna.

# %%
def graficar_establecimiento(establecimiento, ax):

    filtered_df = establecimientos[establecimientos['NOM_RBD'] == establecimiento]
    establecimiento_df = (
        pd.merge(comunas_rm, filtered_df.set_index('COD_COM_ALU'),
                left_on='cod_comuna',
                right_index=True,
                how='left')
        .fillna(0)   
    )

    establecimiento_df.plot(ax=ax,
                           column='n_percent',
                           cmap='BuPu',
                           linewidth=0.2)

    ax.set_title(establecimiento)
    ax.set_axis_off()

# %% [markdown]
# Ahora veamos que establecimientos están disponibles.

# %%
# print(list(pd.unique(establecimientos['NOM_RBD'])))

# %% [markdown]
# Empecemos a probar algunos.

# %%
fig, ax = plt.subplots(1,2, figsize=(16,8))

graficar_establecimiento('LICEO JAVIERA CARRERA', ax[0])
graficar_establecimiento('COLEGIO SAINT GEORGE S COLLEGE', ax[1])

plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(16,8))

graficar_establecimiento('LICEO INSTITUTO NACIONAL', ax[0])
graficar_establecimiento('COLEGIO THE GRANGE SCHOOL', ax[1])

plt.show()

# %% [markdown]
# Este tipo de visualización tiene mucho potencial una vez que se identifiquen establecimientos interesantes. En principio se podría hacer una infografía o un póster usando *small multiples*, pero eso queda como trabajo extra.

# %% [markdown]
# ## Parte 3: Creando un índice de pobreza por establecimiento

# %% [markdown]
# Ahora que tenemos el porcentaje de estudiantes que vienen de distintas comunas, podríamos ocupar datos comunales para derivar otros indicadores. Por ejemplo, podríamos buscar datos de tasa de pobreza por comuna y ver cómo usar es para caracterizar la población de cada establecimiento educacional.
#
# Los datos de tasas de pobreza comunales pueden ser sacados de la [Encuesta Casen](http://observatorio.ministeriodesarrollosocial.gob.cl/encuesta-casen-en-pandemia-2020).

# %%
casen = pd.read_excel('../data/casen/Estimaciones_de_Tasa_de_Pobreza_por_Ingresos_por_Comunas_2020.xlsx', skiprows=2)
casen.head()
# Out:
#   Código                    Región  Nombre comuna  \
# 0  15101  XV de Arica y Parinacota          Arica
# 1  15102  XV de Arica y Parinacota      Camarones
# 2  15201  XV de Arica y Parinacota          Putre
# 3  15202  XV de Arica y Parinacota  General Lagos
# 4   1101             I de Tarapacá        Iquique
#
#    Número de personas según proyecciones de población (*)  \
# 0                                           248820.0
# 1                                             1236.0
# 2                                             2124.0
# 3                                              674.0
# 4                                           224971.0
#
#    Número de personas en situación de pobreza por ingresos (**)  \
# 0                                       29253.933643
# 1                                         281.731865
# 2                                         434.211318
# 3                                         173.837157
# 4                                       27794.643614
#
#    Porcentaje de personas en situación de pobreza por ingresos 2020  \
# 0                                           0.117571
# 1                                           0.227938
# 2                                           0.204431
# 3                                           0.257919
# 4                                           0.123548
#
#    Límite inferior  Límite superior  \
# 0         0.102854         0.132287
# 1         0.156078         0.299798
# 2         0.143767         0.265095
# 3         0.185909         0.329928
# 4         0.106849         0.140246
#
#   Presencia de la comuna en la muestra Casen  \
# 0                                         Si
# 1                                         Si
# 2                                         Si
# 3                                         No
# 4                                         Si
#
#         Tipo de estimación SAE (***)
# 0  Directa y Sintética (Fay-Herriot)
# 1                          Sintética
# 2                          Sintética
# 3                          Sintética
# 4  Directa y Sintética (Fay-Herriot)

# %% [markdown]
# Filtramos sólo los datos de la Región Metropolitana.

# %%
casen_rm = casen[casen['Región'] == 'XIII Metropolitana de Santiago'].reset_index()
casen_rm.head()
# Out:
#    index Código                          Región Nombre comuna  \
# 0     82  13101  XIII Metropolitana de Santiago      Santiago
# 1     83  13102  XIII Metropolitana de Santiago     Cerrillos
# 2     84  13103  XIII Metropolitana de Santiago   Cerro Navia
# 3     85  13104  XIII Metropolitana de Santiago      Conchalí
# 4     86  13105  XIII Metropolitana de Santiago     El Bosque
#
#    Número de personas según proyecciones de población (*)  \
# 0                                           508785.0
# 1                                            89174.0
# 2                                           142391.0
# 3                                           139274.0
# 4                                           171889.0
#
#    Número de personas en situación de pobreza por ingresos (**)  \
# 0                                       42878.203660
# 1                                        8020.140239
# 2                                       18328.187345
# 3                                       17331.889326
# 4                                       21590.830268
#
#    Porcentaje de personas en situación de pobreza por ingresos 2020  \
# 0                                           0.084276
# 1                                           0.089938
# 2                                           0.128717
# 3                                           0.124445
# 4                                           0.125609
#
#    Límite inferior  Límite superior  \
# 0         0.062351         0.106200
# 1         0.061526         0.118350
# 2         0.093194         0.164240
# 3         0.091285         0.157604
# 4         0.094112         0.157107
#
#   Presencia de la comuna en la muestra Casen  \
# 0                                         Si
# 1                                         Si
# 2                                         Si
# 3                                         Si
# 4                                         Si
#
#         Tipo de estimación SAE (***)
# 0  Directa y Sintética (Fay-Herriot)
# 1  Directa y Sintética (Fay-Herriot)
# 2  Directa y Sintética (Fay-Herriot)
# 3  Directa y Sintética (Fay-Herriot)
# 4  Directa y Sintética (Fay-Herriot)

# %% [markdown]
# Aquí la idea es tener un indicador de situación socioeconómica por establecimiento educacional. Para eso, calcularemos un promedio usando como peso el porcentaje de estudiantes de esa comuna.

# %%
def weighted_mean(df, value='Porcentaje de personas en situación de pobreza por ingresos 2020', weight='n_percent'):
    weighted_sum = (df[value] * df[weight]).sum()
    return weighted_sum

# %% [markdown]
# Hay que tener cuidado como se manejan los datos para poder mezclarlos y hacer operaciones en ellos.

# %%
tasa_pobreza = (
    pd.merge(establecimientos, casen_rm.set_index('Código'),
            left_on='COD_COM_ALU',
            right_index=True)
    .groupby(['RBD'])
    .apply(weighted_mean)
    .reset_index()
)
tasa_pobreza.columns = ['RBD', 'TASA_POBREZA']
tasa_pobreza.head()
# Out:
# /Users/fbecerra/Library/Python/3.8/lib/python/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
#     RBD  TASA_POBREZA
# 0  8485      0.097376
# 1  8487      0.101343
# 2  8488      0.101713
# 3  8489      0.102680
# 4  8490      0.095742

# %% [markdown]
# Información adicional que nos va a servir en nuestro análisis es el tipo de subvención que tiene cada establecimiento: municipal, particular subvencionado o particular pagado. Por lo que agregamos esa columna a nuestro dataframe.

# %%
depe = (
    df_rm.groupby('RBD')
        .first()
        .reset_index()[['RBD', 'NOM_RBD', 'COD_DEPE2']]
)
depe.head()
# Out:
#     RBD                                 NOM_RBD  COD_DEPE2
# 0  8485                LICEO INSTITUTO NACIONAL          1
# 1  8487                   LICEO JAVIERA CARRERA          1
# 2  8488  LICEO N° 4 BICENTENARIO ISAURA DINATOR          1
# 3  8489         LICEO BICENTENARIO TERESA PRATS          1
# 4  8490      LICEO NRO 2 MIGUEL LUIS AMUNATEGUI          1

# %% [markdown]
# Y lo mezclamos con nuestros datos

# %%
rbd_pobreza = tasa_pobreza.merge(depe)
rbd_pobreza.head()
# Out:
#     RBD  TASA_POBREZA                                 NOM_RBD  COD_DEPE2
# 0  8485      0.097376                LICEO INSTITUTO NACIONAL          1
# 1  8487      0.101343                   LICEO JAVIERA CARRERA          1
# 2  8488      0.101713  LICEO N° 4 BICENTENARIO ISAURA DINATOR          1
# 3  8489      0.102680         LICEO BICENTENARIO TERESA PRATS          1
# 4  8490      0.095742      LICEO NRO 2 MIGUEL LUIS AMUNATEGUI          1

# %% [markdown]
# Ahora graficamos las distribuciones de los establecimientos en base al índice de pobreza que recién calculamos. Para hacer el análisis más interesante, lo dividiremos según el tipo de subvención que reciba el establecimiento.

# %%
labels = ['Municipal', 'Particular Subvencionado', 'Particular Pagado']
colors = ['#377eb8', '#ff7f00', '#4daf4a']

fig, ax = plt.subplots(1,2, figsize=(16,6))

for depe in range(1,4):
    filtered = rbd_pobreza[rbd_pobreza['COD_DEPE2'] == depe]
    filtered.hist(column='TASA_POBREZA', ax=ax[0], alpha=0.5, label=labels[depe-1], bins=100, color=colors[depe-1])
    
    filtered['TASA_POBREZA'].plot.kde(ax=ax[1], label=labels[depe-1], color=colors[depe-1])

ax[0].legend()
ax[1].legend()
plt.show()

# %% [markdown]
# Otra de mis visualizaciones favoritas para representar distribuciones es el `beeswarm`. Afortunadamente, `seaborn` trae una función que nos permite crearla de una forma sencilla.

# %%
labels = ['Municipal', 'Particular Subvencionado', 'Particular Pagado']
colors = ['#377eb8', '#ff7f00', '#4daf4a']

fig, ax = plt.subplots(3,1, figsize=(10,6), sharex=True)

for depe in range(1,4):
    filtered = rbd_pobreza[rbd_pobreza['COD_DEPE2'] == depe]
    sns.swarmplot(x=filtered['TASA_POBREZA'], ax=ax[depe-1], alpha=0.9,
                  label=labels[depe-1], color=colors[depe-1], size=2)
    
    ax[depe-1].set_xlim(0.02, 0.16)
    ax[depe-1].set_yticklabels([labels[depe-1]])
    ax[depe-1].text(0, 0, labels[depe-1], color=colors[depe-1])
    
    if (depe == 3):
        for key, spine in ax[depe-1].spines.items():
            spine.set_visible(False)
        ax[depe-1].spines['left'].set_visible(False)
        ax[depe-1].spines['right'].set_visible(False)
        ax[depe-1].xaxis.label.set_color('#525252')
        ax[depe-1].tick_params(axis='x', colors='#525252')
        ax[depe-1].set_xlabel('Tasa pobreza')
        ax[depe-1].set_yticks([])
    else:
        ax[depe-1].set_axis_off()
    
fig.suptitle('akjdnfkasjfks', x=0.008, y=0.98, ha='left')
fig.tight_layout()
plt.subplots_adjust(hspace=0)
plt.show()

# %% [markdown]
# Encontrar los comandos correctos para borrar `ticks`, `ticklabels` y `spines` puede tomar tiempo, así que dejo [este enlace](https://stackabuse.com/matplotlib-turn-off-axis-spines-ticklabels-axislabels-grid/) que los puede ayudar a personalizar sus gráficos. Igual que en la parte anterior, hay mucho que se le puede agregar y mejorar a esta visualización, por lo que eso también queda como ejercicio para cada uno de ustedes.

# %% [markdown]
# ## Parte 4: Comparación índice de pobreza con resultados SIMCE

# %% [markdown]
# Para poder comparar pobreza con resultados en pruebas estandarizadas, debemos cargar nuevos datos. Esta vez, los sacamos de [la base de datos del SIMCE](https://informacionestadistica.agenciaeducacion.cl/#/bases).

# %%
simce = pd.read_excel('../data/educacion/Simce8b2019_publicas_web/Archivos XLS (XLSX)/simce8b2019_rbd.xlsx')
simce.head()
# Out:
#    agno grado  rbd  dvrbd                                  nom_rbd  \
# 0  2019    8b    5      1                 JOVINA NARANJO FERNANDEZ
# 1  2019    8b    8      6  COLEGIO INTEGRADO EDUARDO FREI MONTALVA
# 2  2019    8b    9      4              ESCUELA REPUBLICA DE ISRAEL
# 3  2019    8b   10      8             ESCUELA REPUBLICA DE FRANCIA
# 4  2019    8b   11      6          ESC. GRAL. PEDRO LAGOS MARCHANT
#
#    cod_reg_rbd            nom_reg_rbd  cod_pro_rbd nom_pro_rbd  cod_com_rbd  \
# 0           15  DE ARICA Y PARINACOTA          151       ARICA        15101
# 1           15  DE ARICA Y PARINACOTA          151       ARICA        15101
# 2           15  DE ARICA Y PARINACOTA          151       ARICA        15101
# 3           15  DE ARICA Y PARINACOTA          151       ARICA        15101
# 4           15  DE ARICA Y PARINACOTA          151       ARICA        15101
#
#    ... siggru_soc8b_rbd  marca_lect8b_rbd marca_mate8b_rbd  marca_soc8b_rbd  \
# 0  ...              1.0               NaN              NaN              NaN
# 1  ...              0.0               NaN              NaN              NaN
# 2  ...              0.0               NaN              NaN              NaN
# 3  ...              0.0               NaN              NaN              NaN
# 4  ...             -1.0               NaN              NaN              NaN
#
#    marcadif_lect8b_rbd  marcadif_mate8b_rbd  marcadif_soc8b_rbd  noaplica  \
# 0                  NaN                  NaN                 NaN         0
# 1                  NaN                  NaN                 NaN         0
# 2                  NaN                  NaN                 NaN         0
# 3                  NaN                  NaN                 NaN         0
# 4                  NaN                  NaN                 NaN         0
#
#    fecha_bbdd      codigo_bbdd
# 0    20200807  final20200811v2
# 1    20200807  final20200811v2
# 2    20200807  final20200811v2
# 3    20200807  final20200811v2
# 4    20200807  final20200811v2
#
# [5 rows x 44 columns]

# %% [markdown]
# Y filtramos sólo los establecimientos con los cuales hemos estado trabajando hasta el momento.

# %%
simce_rm = simce[simce['rbd'].isin(rbd_pobreza['RBD'])]
simce_rm.head()
# Out:
#       agno grado   rbd  dvrbd                             nom_rbd  \
# 2961  2019    8b  8485      9            LICEO INSTITUTO NACIONAL
# 2962  2019    8b  8487      5               LICEO JAVIERA CARRERA
# 2963  2019    8b  8488      3      LICEO ISAURA DINATOR DE GUZMAN
# 2964  2019    8b  8489      1     LICEO BICENTENARIO TERESA PRATS
# 2965  2019    8b  8490      5  LICEO NRO 2 MIGUEL LUIS AMUNATEGUI
#
#       cod_reg_rbd            nom_reg_rbd  cod_pro_rbd nom_pro_rbd  \
# 2961           13  METROPOLITANA DE SANT          131       SANTI
# 2962           13  METROPOLITANA DE SANT          131       SANTI
# 2963           13  METROPOLITANA DE SANT          131       SANTI
# 2964           13  METROPOLITANA DE SANT          131       SANTI
# 2965           13  METROPOLITANA DE SANT          131       SANTI
#
#       cod_com_rbd  ... siggru_soc8b_rbd  marca_lect8b_rbd marca_mate8b_rbd  \
# 2961        13101  ...              1.0               NaN              NaN
# 2962        13101  ...              1.0               NaN              NaN
# 2963        13101  ...             -1.0               NaN              NaN
# 2964        13101  ...             -1.0               NaN              NaN
# 2965        13101  ...             -1.0               NaN              NaN
#
#       marca_soc8b_rbd  marcadif_lect8b_rbd  marcadif_mate8b_rbd  \
# 2961              NaN                  NaN                  NaN
# 2962              NaN                  NaN                  NaN
# 2963              NaN                  NaN                  NaN
# 2964              NaN                  NaN                  NaN
# 2965              NaN                  NaN                  NaN
#
#       marcadif_soc8b_rbd  noaplica  fecha_bbdd      codigo_bbdd
# 2961                 NaN         0    20200807  final20200811v2
# 2962                 NaN         0    20200807  final20200811v2
# 2963                 NaN         0    20200807  final20200811v2
# 2964                 NaN         0    20200807  final20200811v2
# 2965                 NaN         0    20200807  final20200811v2
#
# [5 rows x 44 columns]

# %% [markdown]
# Exploramos las columnas disponibles para saber cuáles nos servirán.

# %%
simce_rm.columns
# Out:
# Index(['agno', 'grado', 'rbd', 'dvrbd', 'nom_rbd', 'cod_reg_rbd',
#        'nom_reg_rbd', 'cod_pro_rbd', 'nom_pro_rbd', 'cod_com_rbd',
#        'nom_com_rbd', 'cod_deprov_rbd', 'nom_deprov_rbd', 'cod_depe1',
#        'cod_depe2', 'cod_grupo', 'cod_rural_rbd', 'nalu_lect8b_rbd',
#        'nalu_mate8b_rbd', 'nalu_soc8b_rbd', 'prom_lect8b_rbd',
#        'prom_mate8b_rbd', 'prom_soc8b_rbd', 'dif_lect8b_rbd', 'dif_mate8b_rbd',
#        'dif_soc8b_rbd', 'difgru_lect8b_rbd', 'difgru_mate8b_rbd',
#        'difgru_soc8b_rbd', 'sigdif_lect8b_rbd', 'sigdif_mate8b_rbd',
#        'sigdif_soc8b_rbd', 'siggru_lect8b_rbd', 'siggru_mate8b_rbd',
#        'siggru_soc8b_rbd', 'marca_lect8b_rbd', 'marca_mate8b_rbd',
#        'marca_soc8b_rbd', 'marcadif_lect8b_rbd', 'marcadif_mate8b_rbd',
#        'marcadif_soc8b_rbd', 'noaplica', 'fecha_bbdd', 'codigo_bbdd'],
#       dtype='object')

# %% [markdown]
# Definimos las que tengan puntajes de las pruebas para usarlas después.

# %%
pruebas_simce = ['prom_lect8b_rbd', 'prom_mate8b_rbd', 'prom_soc8b_rbd']
simce_rm = simce_rm[pruebas_simce + ['rbd']]
simce_rm.columns = pruebas_simce + ['RBD']
simce_rm.head()
# Out:
#       prom_lect8b_rbd  prom_mate8b_rbd  prom_soc8b_rbd   RBD
# 2961            257.0            291.0           276.0  8485
# 2962            246.0            269.0           262.0  8487
# 2963            249.0            260.0           238.0  8488
# 2964            252.0            257.0           249.0  8489
# 2965            203.0            228.0           222.0  8490

# %%
rbd_pobreza.head()
# Out:
#     RBD  TASA_POBREZA                                 NOM_RBD  COD_DEPE2
# 0  8485      0.097376                LICEO INSTITUTO NACIONAL          1
# 1  8487      0.101343                   LICEO JAVIERA CARRERA          1
# 2  8488      0.101713  LICEO N° 4 BICENTENARIO ISAURA DINATOR          1
# 3  8489      0.102680         LICEO BICENTENARIO TERESA PRATS          1
# 4  8490      0.095742      LICEO NRO 2 MIGUEL LUIS AMUNATEGUI          1

# %% [markdown]
# Los mezclamos con nuestro dataset

# %%
simce_pobreza = rbd_pobreza.merge(simce_rm)
simce_pobreza.head()
# Out:
#     RBD  TASA_POBREZA                                 NOM_RBD  COD_DEPE2  \
# 0  8485      0.097376                LICEO INSTITUTO NACIONAL          1
# 1  8487      0.101343                   LICEO JAVIERA CARRERA          1
# 2  8488      0.101713  LICEO N° 4 BICENTENARIO ISAURA DINATOR          1
# 3  8489      0.102680         LICEO BICENTENARIO TERESA PRATS          1
# 4  8490      0.095742      LICEO NRO 2 MIGUEL LUIS AMUNATEGUI          1
#
#    prom_lect8b_rbd  prom_mate8b_rbd  prom_soc8b_rbd
# 0            257.0            291.0           276.0
# 1            246.0            269.0           262.0
# 2            249.0            260.0           238.0
# 3            252.0            257.0           249.0
# 4            203.0            228.0           222.0

# %% [markdown]
# Y graficamos para ver que relación hay entre esas variables

# %%
fig, ax = plt.subplots(1, len(pruebas_simce), figsize=(14,4))
xmin = 0.02
xmax = 0.15

for idx, col in enumerate(pruebas_simce):
    simce_pobreza.plot.scatter('TASA_POBREZA', col, ax=ax[idx], alpha=0.2)
    ax[idx].set_xlim(xmin, xmax)
    ax[idx].set_ylim(150, 380)
    
plt.show()

# %% [markdown]
# Ahí se ve algo interesante (y lamentablemente esperable)... ¿hay algun tipo de relación? Tratemos de ajustar un modelo lineal para ver que sale. Para eso ocuparemos el paquete `scipy`.

# %%
import scipy as sp

# %%
fig, ax = plt.subplots(1, len(pruebas_simce), figsize=(14,4))
xmin = 0.02
xmax = 0.15

for idx, col in enumerate(pruebas_simce):
    simce_pobreza.plot.scatter('TASA_POBREZA', col, ax=ax[idx], alpha=0.2)
    b, a, r, p, err = sp.stats.linregress(simce_pobreza['TASA_POBREZA'], simce_pobreza[col])
    
    x = np.linspace(xmin, xmax, 100)
    ax[idx].plot(x, a + b * x, color='#984ea3', lw=1.5)
    
    ax[idx].text(0.12, 365, 'R = {:.2f}'.format(r))
    ax[idx].set_xlim(xmin, xmax)
    ax[idx].set_ylim(150, 380)
    
plt.show()

# %% [markdown]
# La línea no se ve porque hay `nan` dentro del dataframe, así que nos tenemos que deshacer de ellos para que funcione.

# %%
simce_pobreza_clean = simce_pobreza.dropna().sort_values(by='TASA_POBREZA')

# %%
fig, ax = plt.subplots(1, len(pruebas_simce), figsize=(14,4))
xmin = 0.02
xmax = 0.15

for idx, col in enumerate(pruebas_simce):
    simce_pobreza_clean.plot.scatter('TASA_POBREZA', col, ax=ax[idx], alpha=0.2)
    b, a, r, p, err = sp.stats.linregress(simce_pobreza_clean['TASA_POBREZA'], simce_pobreza_clean[col])
    
    x = np.linspace(xmin, xmax, 100)
    ax[idx].plot(x, a + b * x, color='#984ea3', lw=1.5)
    
    ax[idx].text(0.12, 365, 'R = {:.2f}'.format(r))
    ax[idx].set_xlim(xmin, xmax)
    ax[idx].set_ylim(150, 380)
    
plt.show()

# %% [markdown]
# Ahora, sería interesante hacer este mismo gráfico pero diferenciado por tipo de subvención.

# %%
fig, ax = plt.subplots(1, len(pruebas_simce), figsize=(14,4))

xmin = 0.02
xmax = 0.15

for idx, col in enumerate(pruebas_simce):
    for depe, label in enumerate(labels):
        depe_simce = simce_pobreza_clean[simce_pobreza_clean['COD_DEPE2'] == depe + 1]
        depe_simce.plot.scatter('TASA_POBREZA', col, ax=ax[idx], alpha=0.2, color=colors[depe])
        
        b, a, r, p, err = sp.stats.linregress(depe_simce['TASA_POBREZA'], depe_simce[col])
        x = np.linspace(xmin, xmax, 100)
        ax[idx].plot(x, a + b * x, color=colors[depe], lw=1.5)

#         ax[idx].text(0.12, 365, 'R = {:.2f}'.format(r))
        ax[idx].set_xlim(xmin, xmax)
        ax[idx].set_ylim(150, 380)
    
plt.show()

# %% [markdown]
# Y sería mejor aún si los separamos en distintos gráficos para ver todo más claramente.

# %%
fig, ax = plt.subplots(len(labels), len(pruebas_simce), figsize=(14,12))

xmin = 0.02
xmax = 0.15

for idx, col in enumerate(pruebas_simce):
    for depe, label in enumerate(labels):
        depe_simce = simce_pobreza_clean[simce_pobreza_clean['COD_DEPE2'] == depe + 1]
        depe_simce.plot.scatter('TASA_POBREZA', col, ax=ax[depe][idx], alpha=0.2, color=colors[depe])
        
        b, a, r, p, err = sp.stats.linregress(depe_simce['TASA_POBREZA'], depe_simce[col])
        x = np.linspace(xmin, xmax, 100)
        ax[depe][idx].plot(x, a + b * x, color='#984ea3', lw=1.5)

        ax[depe][idx].text(0.12, 365, 'R = {:.2f}'.format(r))
        ax[depe][idx].set_xlim(xmin, xmax)
        ax[depe][idx].set_ylim(150, 380)
    
plt.show()

# %% [markdown]
# Recién ahora me dí cuenta de algo que no hemos considerado: el total de estudiantes por establecimiento.

# %%
n_total = (
    df_rm.groupby(['RBD'])
        .agg(n_total=('COD_COM_ALU', 'count'))
        .reset_index()
)
n_total.head()
# Out:
#     RBD  n_total
# 0  8485     3612
# 1  8487     2559
# 2  8488      398
# 3  8489      442
# 4  8490      476

# %% [markdown]
# Y lo mezclamos con nuestro dataframe.

# %%
simce_pobreza_total = simce_pobreza_clean.merge(n_total).dropna()
simce_pobreza_total.head()
# Out:
#      RBD  TASA_POBREZA                                       NOM_RBD  \
# 0   8873      0.029188                   COLEGIO VILLA MARIA ACADEMY
# 1   8991      0.030075  COLEGIO PADRE HURTADO Y JUANITA DE LOS ANDES
# 2   8872      0.031499                        COLEGIO WENLOCK SCHOOL
# 3  11968      0.031560                               COLEGIO CUMBRES
# 4  24409      0.031814                   COLEGIO SAN NICOLAS DE MYRA
#
#    COD_DEPE2  prom_lect8b_rbd  prom_mate8b_rbd  prom_soc8b_rbd  n_total
# 0          3            289.0            331.0           299.0     1618
# 1          3            284.0            309.0           292.0     1579
# 2          3            305.0            322.0           318.0      777
# 3          3            274.0            328.0           304.0     1270
# 4          3            273.0            319.0           305.0      562

# %% [markdown]
# Lamentablemente el método de `scipy` que ocupamos para ajustar el model lineal no acepta pesos como parámetros, por lo que tenemos que ocupar otro paquete llamado `sklearn`.

# %%
from sklearn.linear_model import LinearRegression

# %%
fig, ax = plt.subplots(len(labels), len(pruebas_simce), figsize=(14,12))

xmin = 0.02
xmax = 0.15

for idx, col in enumerate(pruebas_simce):
    for depe, label in enumerate(labels):
        depe_simce = simce_pobreza_total[simce_pobreza_total['COD_DEPE2'] == depe + 1]
        depe_simce.plot.scatter('TASA_POBREZA', col, ax=ax[depe][idx], alpha=0.2, color=colors[depe])
        
        linreg = LinearRegression()
        # linreg.fit(x, y, weight)
        linreg.fit(depe_simce[['TASA_POBREZA']], depe_simce[[col]], depe_simce['n_total'].to_numpy())
        r = linreg.score(depe_simce[['TASA_POBREZA']], depe_simce[[col]], depe_simce['n_total'].to_numpy())
        
        x = pd.DataFrame(np.linspace(xmin, xmax, 100), columns=['TASA_POBREZA'])
        ax[depe][idx].plot(x[['TASA_POBREZA']], linreg.predict(x[['TASA_POBREZA']]), color='#984ea3', lw=1.5)

        ax[depe][idx].text(0.12, 365, 'R = {:.2f}'.format(r))
        ax[depe][idx].set_xlim(xmin, xmax)
        ax[depe][idx].set_ylim(150, 380)
    
plt.show()

# %% [markdown]
# Hasta acá ya tenemos todo lo necesario para armar una historia, con una narrativa clara y una intención de qué es lo que queremos comunicar. Ahora hay que pasar harto tiempo mejorando los gráficos para que se ven mejor.
